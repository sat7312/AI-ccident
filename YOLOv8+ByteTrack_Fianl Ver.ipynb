# %% [markdown]
# # **정차 차량 탐지 모델: 객체탐지(YOLOv8) + 객체추적(ByteTrack)**
#
# ### 기능: 유저가 직접 영상을 하나 업로드해서 정차 차량이 존재하는지 확인
#
# ### 추가해야할 것: UI, 종합적 사고 판단 로직, 실시간 스트리밍 판단

# %%
# YOLOv8
# !pip install ultralytics

# ByteTrack 의존성
# !pip install cython_bbox lap
# !pip install git+https://github.com/ifzhang/ByteTrack.git
# !pip install loguru
# !pip install python-dotenv
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.154-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.154-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 101.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.154 ultralytics-thop-2.0.14
# Collecting cython_bbox
#   Downloading cython_bbox-0.1.5.tar.gz (4.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lap
#   Downloading lap-0.5.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from cython_bbox) (3.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from cython_bbox) (2.0.2)
# Downloading lap-0.5.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.3 MB/s eta 0:00:00
# Building wheels for collected packages: cython_bbox
#   Building wheel for cython_bbox (setup.py) ... done
#   Created wheel for cython_bbox: filename=cython_bbox-0.1.5-cp311-cp311-linux_x86_64.whl size=105320 sha256=1942a37d31e07f4e9c52aa1f43cc4219fc97f53ebccc8f684b109ec1ccf8fb55
#   Stored in directory: /root/.cache/pip/wheels/98/1b/e6/602b7896bbe63de2bd981e3c322026ffaeb1e70ddeb3f38974
# Successfully built cython_bbox
# Installing collected packages: lap, cython_bbox
# Successfully installed cython_bbox-0.1.5 lap-0.5.12
# Collecting git+https://github.com/ifzhang/ByteTrack.git
#   Cloning https://github.com/ifzhang/ByteTrack.git to /tmp/pip-req-build-d_ghouq7
#   Running command git clone --filter=blob:none --quiet https://github.com/ifzhang/ByteTrack.git /tmp/pip-req-build-d_ghouq7
#   Resolved https://github.com/ifzhang/ByteTrack.git to commit d1bf0191adff59bc8fcfeaa0b33d3d1642552a99
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: yolox
#   Building wheel for yolox (setup.py) ... done
#   Created wheel for yolox: filename=yolox-0.1.0-cp311-cp311-linux_x86_64.whl size=2360299 sha256=db90c047353e0587a91c9b5129b94f11da3cfd83e46385ac44df4765000241f9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dg03b7o2/wheels/d2/f6/27/00e4c654d40c507a4da3a6d8536126323ea375e387ff833c89
# Successfully built yolox
# Installing collected packages: yolox
# Successfully installed yolox-0.1.0
# Collecting loguru
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
from yolox.tracker.byte_tracker import BYTETracker
from argparse import Namespace
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files
import math
import time

# 모델 로드
# model_path = "/content/drive/MyDrive/2025_1학기_캡스톤_12조/yolo_tmp_Streaming+Upload(only 1 class, vehicle-detection).pt"
model_path = "/content/drive/MyDrive/2025_1학기_캡스톤_12조/yolo_tmp_vehicle_detection(car, bus, truck).pt"
model = YOLO(model_path)

# ByteTracker 초기화
tracker_args = Namespace(
    track_thresh=0.25,
    match_thresh=0.8,
    track_buffer=30,
    aspect_ratio_thresh=1.6,
    min_box_area=10,
    mot20=False
)
tracker = BYTETracker(tracker_args, frame_rate=30)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# 사고 판단 기준
STATIONARY_FRAME_THRESHOLD = 5  # 중심 좌표 위치 개수 문턱 값
POSITION_THRESHOLD = 5  # 위치 변화가 N px 이하이면 정지로 판단
ACCIDENT_FRAME_THRESHOLD = 5  # N번 연속 감지되면 사고로 판단
video_is_accident = False

# {track_id: [(x_center, y_center), ...]}  ← 프레임별 위치 저장
track_history = {}

# 사고로 감지된 차량 ID
accident_ids = set()

import numpy as np
np.float = float
np.int = int

# %%
import requests
import os
from dotenv import load_dotenv

load_dotnev()
my_api_key = os.getenv("ITS_API_KEY")

# API 요청 URL
api_url = "https://openapi.its.go.kr:9443/cctvInfo"
params = {
    "apiKey": my_api_key,
    "type": "ex",  # 고속도로
    "cctvType": "1",  # 실시간 스트리밍(HLS)
    "minX": "127.100000",
    "maxX": "128.890000",
    "minY": "34.100000",
    "maxY": "39.100000",
    "getType": "json"
}

# API 요청
response = requests.get(api_url, params=params)
data = response.json()

# CCTV URL 추출
cctv_list = data.get("response", {}).get("data", [])
for cctv in cctv_list:
    print(f"CCTV 이름: {cctv.get('cctvname')}")
    print(f"스트리밍 URL: {cctv.get('cctvurl')}\n")
# Out:
# CCTV 이름: [수도권제1순환선] 성남
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2/WpkGTuzVZyZg7ZPihfeVcucNYv2MCduoKm8PyFub+jly3BoaFwKPxXvDMaGPWl1/gIiuKjolsFVYSm5UuJ4BZg==
#
# CCTV 이름: [수도권제1순환선] 성남요금소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/3/uEaMW6fqLQzhxp12IZdX/CyQH6manYyTLQbKV7bX17SZ/bjw+8EhoMeYi8MWvHA3TKypQcE53b9y4l7VVOO+YA==
#
# CCTV 이름: [수도권제1순환선] 송파
# 스트리밍 URL: http://cctvsec.ktict.co.kr/4/MJXdVNudQ6VqRqEIJgDszilUIwtDWiwV4ygUY4mChkmMTxKleSWcUcpSTo2DU9WLp5Rj2gIk8m0cIzilZOa5WQ==
#
# CCTV 이름: [수도권제1순환선] 서하남2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/5/SlmPC1+Y/XRB4WIG9kreeWwjWftlUPyf7kfFxKBISnAut1fnJczXxagzB+ueNyqh7Z+CO/4Y8LOCgBf9ESqjYw==
#
# CCTV 이름: [수도권제1순환선] 광암터널2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/6/uTf4f3sJvMQyNhpqR4YpACKtIQMup0CC21HZhGjhgRc32ThjRqPqVUOlmQyD63mTCVn+mmclBzT1e7fPq+5AzA==
#
# CCTV 이름: [수도권제1순환선] 광암터널3
# 스트리밍 URL: http://cctvsec.ktict.co.kr/7/nqm7CNfzr/LsFZpjfYLn2J0KLlg2ojkXyVEtFAIVZNSQeKjqyCf+UFbVcNh5HU/ewa3Y4TBJPaf15RdrjIRHUQ==
#
# CCTV 이름: [수도권제1순환선] 하남분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/8/H+RVm6tI2GfQT/KwIhEi3GlQ07CxCj4keRMvgTCcnbvJPbjNN7I5wFL9s32+mtMtgm2J+5WUHDnn8QjywpEb3A==
#
# CCTV 이름: [수도권제1순환선] 상일
# 스트리밍 URL: http://cctvsec.ktict.co.kr/9/PaAzHwvwYGcSVzsJJ/u7GY9RueVbhmJC6ZJ6mKX1IObMbYWPsQTnPProhKzHO4sY12+H/cIAspJprLDKNcDt0Q==
#
# CCTV 이름: [수도권제1순환선] 강일
# 스트리밍 URL: http://cctvsec.ktict.co.kr/10/g2XmL7vjrpbEla2KK5vEtcoopVp9nwI/zAj2C/nbJVdftX3HQTOE8KeL3RT3d+ri5giJzQonfHlMvDu227cshsYOSYjThE9yHSmH3X/HKHs=
#
# CCTV 이름: [수도권제1순환선] 토평
# 스트리밍 URL: http://cctvsec.ktict.co.kr/11/CsoExqkFfsqYZ98v3M8nwcuh+WS44N31ruwM8bVZVi5S60vbH63r1vsODj1HLMJXUvGn8SVcF5h0bEeJi9HuZtPPyMPb114blkXGI0bpXXw=
#
# CCTV 이름: [수도권제1순환선] 남양주
# 스트리밍 URL: http://cctvsec.ktict.co.kr/12/iPb20J+Ez+G/iN2v+WSIE4DQVFXjBmgzIxLS/xWpU2iRkn9Lcl0MB1InxTqGGYXkJP5fn7b2mPAVXpSGrrNo7v1oZG9cO5iNwhDbu9KqCzY=
#
# CCTV 이름: [수도권제1순환선] 퇴계원
# 스트리밍 URL: http://cctvsec.ktict.co.kr/16/5aYPyOgYov2MLIunfqwQ4FIVXZwyDkHYuO1yGqA/w+AaZF/AHakeOxGgxqqy8mPC0Bpji5T/stJqCZNo8v7WYkB275DMjd72onMgzfKvclY=
#
# CCTV 이름: [수도권제1순환선] 구리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/17/E5jpb5Emw3CODLFnx7FHZPVINnj0kgT3eRVNDrdisln1I3Z6eiObh+apPFEpBpMbWvf+i4DfzP+dqag588sB2nUKWZW6G9fClGYjtFC4hhM=
#
# CCTV 이름: [중부선] 상산곡교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/18/KikCUHsyPm/0QSLuGC8VbYPj6lDslaQrSwHeiuAXHyk1dSohUTLmLeNr/0+RPE06sRIgQBJI9m4G4LVT7D7T4hr32XhzPxK1y4g/ul7q9+o=
#
# CCTV 이름: [중부선] 하산곡
# 스트리밍 URL: http://cctvsec.ktict.co.kr/19/7N7lEDAJPvm1reMibF8SA+sGNAuktX2Hxi6aU3RuNKZXrbFFRODM3j2g0As7PrpkH+bENQwK/LOIif5jBa9SHJ7Hk4h+0IY/fOE5lQBvoHM=
#
# CCTV 이름: [중부선] 동서울영업소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/20/DKPjfY8PcD9A7l8WHsZNv1J2d8gGyRLkLT7QTSwmlWG7C12h4asaet+6vI1a4B8hUj3CVaBsIzAmHMEU1n3IUyX/gD66wFRZ+HM4xdKc22Q=
#
# CCTV 이름: [중부선] 하남
# 스트리밍 URL: http://cctvsec.ktict.co.kr/21/RTI/2HN9aVxkpkYzXdeTSgjxKR7WRZe3bnd6rZcMtceo2c46F+LZQ2syB0lCom1gtq80GNpFbzgm+0436piWBcIn18fl9ZVLShDvMXzJwAY=
#
# CCTV 이름: [중부선] 일죽
# 스트리밍 URL: http://cctvsec.ktict.co.kr/22/n0WRocaOM6tMKkowGfjhciSdw/scU3NJpVX4MVMLThL9rJHPiOM+jqwpxp/jXTk5JdWpOxcM66laGkr0zrgSLr4czFbja6uqvLVvNy6JNGo=
#
# CCTV 이름: [중부선] 모가
# 스트리밍 URL: http://cctvsec.ktict.co.kr/23/TIcPpjFsQkaYk8BTTF4RlBCB8CWBed3UJ/OX803irDOMmzrCT5km5ETE8goApEhwbP1eUE6pg7IRGz9HUmZxhpuMI3PXIaWjlVQJx5J70Fs=
#
# CCTV 이름: [제2중부선] 진우1육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/24/QduR2ExbTU0Zri8anE2PlzoZI+wj7EfCVSaRIvKEdqV8vg6cm9SRzfJHVNs9eTl9nZvUHoGEk6hAKTzqdsa11vkfhXwLpFqHdoHqBiS2uUc=
#
# CCTV 이름: [제2중부선] 초월
# 스트리밍 URL: http://cctvsec.ktict.co.kr/25/KMtWbNwKkFRw8mGPq9BjqT6Qw/bfCUhlHkJZ4bKvZW+2+aI1LICjZz+XDzewL8aPFIvdtiCnImehccs7FyeWweJflwq6iTbIOr19DH6OTjE=
#
# CCTV 이름: [중부선] 호법분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/26/ZXo9ButZdp79VeTju4ADumSllPcsbTxfll7r1oCmUvOGgUneekH5cNvZ1FEFWjnQIBeCWAUFbltjnleSsjXv33ai3ZodFIjN+PSD9niE9g4=
#
# CCTV 이름: [중부선] 서이천
# 스트리밍 URL: http://cctvsec.ktict.co.kr/27/l1z+Puqp20TIdV5772T0BDaPK7jvzTlQPjy/7wAjchlr7u683nuVpCo1vCnWmkvV1HTMurdGmen8/6L42HpbwigucT8NlYv8gtvDDqNqki0=
#
# CCTV 이름: [중부선] 곤지암
# 스트리밍 URL: http://cctvsec.ktict.co.kr/28/Ff4j4z/hEmbugyM8DSVwVPExTwdZUuTJEy0rfx0JW9w5k1HDi3+/O+HpAuIIY4UIVQspuWGVPe1Y4BxEJZKCs1J11P7/nt3PTA23m1MTAIs=
#
# CCTV 이름: [중부선] 중부3터널
# 스트리밍 URL: http://cctvsec.ktict.co.kr/29/t1+/6V7F4MLikabLXRiJtUEbspwPOtA4fWjF/ZL0i0QNr015N2s782+fyOUlHOIk0Rmr+n5g15fzoDAPgsmWysA9MAsBArJ06zprcBFg/kU=
#
# CCTV 이름: [중부선] 중부2터널
# 스트리밍 URL: http://cctvsec.ktict.co.kr/30/JUBz7AzrJpWz6L/vumYUMvHye05i3+A46FvQiZNQCFSqjHs4TFYh6k2LPRGzRo/z9pdEwOSai7YUFoO5rPxvhBUxsVAeuMbWl7LUL5kvLDw=
#
# CCTV 이름: [중부선] 광주
# 스트리밍 URL: http://cctvsec.ktict.co.kr/31/COB+fg1R6I1LsCQ1SEx9Qk/S+OasSMTM/z4iEuBy3Gz/0XimowxJEjzpuBq7QLb5juZDDv5bGNRad4CrdGxgjni5UDIIR6BEzJ9yNcgr3X0=
#
# CCTV 이름: [제2중부선] 광지원터널
# 스트리밍 URL: http://cctvsec.ktict.co.kr/32/CEQBL+vMmOff0I72fssqLXIhE10RzQfd4Ab/dwCyNBv3y9Cvs/0F7DR84vHWc1p0NeQxLsSutipSEAO1UiYVgVUpfmGBB3rrjWAe45r/Kig=
#
# CCTV 이름: [중부선] 광지원2교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/33/dj6EqPlTAuLO7u4rYnU1sAE7c5XwHxZmV8lMhlLHp2roMpY8dZe8ZaiEzz0UB/06DBdPRVRpMPsiBfa0sHRk3M3oqatHYkzaOOfgJo+LuVc=
#
# CCTV 이름: [중부선] 중부1터널
# 스트리밍 URL: http://cctvsec.ktict.co.kr/34/rHSE7MB2YZDYboX6BUbpHv0V7L8BHihPblQOFoVvjdsgcsunVKjn6zudI6lRJRcUlaStYE6GsQoXsrhVOFxoVyHlpfE5aXHRx4jBoxHDw9s=
#
# CCTV 이름: [중부선] 산곡분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/35/UjUeeEgYrMbl/RJKbBav0QXOK1mQJ0FLQ+Jz3eMKgLzO/w9W5F6ng9dN/3f/uimnWb5BdzaJYHv/3QAxGNvp2dQ3K4GPD3lgwVcZzmvopzg=
#
# CCTV 이름: [경부선] 안성휴게소(서울)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/72/H8/4EJV9V3zEMn/OBEbNVskgykL2Tpz4jmtoDtQoXkhcHyrbFJnwlyQF6lVL5vvxN1tZfng8RW8iiHY72b7tyfl/f5qkl/IbkVkHOl0E97k=
#
# CCTV 이름: [경부선] 기흥
# 스트리밍 URL: http://cctvsec.ktict.co.kr/74/SSuShqHTtsqLDis3i4q2l+WeNwxSFt7Sq8Shz4X+pYN+/bHGSHjQX2QkCoFL6FPNr7v2k6P1iOHtdoWYc+qYA/Dk088fVUy0fbFDIE4xee8=
#
# CCTV 이름: [경부선] 수원
# 스트리밍 URL: http://cctvsec.ktict.co.kr/75/bLMeQgD682ppZASh6P8OKfeBC6gXr685pc65Zm9KVGmATyZxZLUsMJxmya77b6dXjaooVb4Mutba9UFhAp19qaSB2gtu2OKagPub1pyR9Pc=
#
# CCTV 이름: [경부선] 신갈분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/76/4q8gAyJ1oJn6KCgsQ2tDXeme91IO0jva0ge/5lz8PP0HSerp5EOXq/87YJTahpaQjdBUmhlIJRE4GCLpFRUo77ISZ2jM0HUSsdsvJlov40w=
#
# CCTV 이름: [경부선] 죽전휴게소(서울)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/77/wJYFZ1yiEgsmXU0l/0uyf/q+x5HbHpFh0t0JZlJVH8YZa/LcGFfpkKb5I6uyFGELnVKtpDWNsZ2Deh9CWVZC2Sk4dDf/LmPpvsmMDqHV/qk=
#
# CCTV 이름: [경부선] 서울영업소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/78/9nOmgkWq4QI3Xo/K3KTvt/QbFKuqaa56yoMnz94+5Lr8YsA36hiEFgdpfe1mdgwMgzPu1jLNyWc3geK9axGKCisHhq68mI0RpbekIMjmKwU=
#
# CCTV 이름: [경부선] 판교2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/79/Ya2e5p36Gr44WJO5/CQwGohtZMV+ZK4Im3bYC0eyjmTO2VmX26pyLEj2sqSe8t89MP6H6QX68QLNcn64EiPyeVnIt2xpimYXgR2/kNTj5Ds=
#
# CCTV 이름: [경부선] 죽전
# 스트리밍 URL: http://cctvsec.ktict.co.kr/80/91AZgGks7myuY5JD11P3vGG4zOH4akEx4v+T4ivCCu7z0SJsR9m9zclCh6QRV+//R4zMigTbaoG30nQIWwwgkryptO8FFyLM3OIXeWNyZJ0=
#
# CCTV 이름: [영동선] 마성터널(인천)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/83/tVmIPdeNTM17CNZ9FOzhgAuuxkEEM8diuAf1NQmpBcTGEyHy323oc2UQ1xbItnLNtu5UfHKNxdEpKnlvO0EyucbA8VlzxbZTPsjEZvPPNLs=
#
# CCTV 이름: [영동선] 용인
# 스트리밍 URL: http://cctvsec.ktict.co.kr/84/Ml0vHOQ4rgXdIJ5pxulXYZ7h745VN//s1bAkRhYr5tirjeYU6W2w6MMR/4QrTcxpDCs9q5mPrfI+Tcqv6ddAXW9VyoZksLk/EIPXSvAjAdQ=
#
# CCTV 이름: [영동선] 양지터널(강릉)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/85/Z+J07qvnZEH22UaNHasQ7q2TFTKSHzrXxsuglh7PUBFgo+shYpqAF5yKxRLZ+qVsqVpdI+6rYTUcbj7+X022YbJe3/mLkL2rZ5bFBzrKCJA=
#
# CCTV 이름: [영동선] 양지
# 스트리밍 URL: http://cctvsec.ktict.co.kr/86/3ZUkq8lAG3nLFvZfzBEjIkDcs7+1Hn+4/Zx/UUIJN3O1g3ou8ojoB3amp2DVbgoWPoZOyUjg20L73Hhqjt78LTgGzPJVtjc6VUD+zmx75Ow=
#
# CCTV 이름: [영동선] 오천교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/87/uoRZYmIQNhPZM4EnhfoOHvLiBCZjyJP9HP6y5aW6bNFhdMJZgSZ4GGc2JAfGtVsV6p5y8GS4BOsEXFAxzHHfRsNWAmXZVGm5x79szDi2kgE=
#
# CCTV 이름: [영동선] 덕평
# 스트리밍 URL: http://cctvsec.ktict.co.kr/88/35anlulxVsLWgypHajs8C3z48cDOtxN4e+2FLGZTOhkOy2YT5MTxA8v1xd7/EZfwrIVcE3Yi1+CwnpgGnAiOWRikzdStJZrxZgxCLjKmxqo=
#
# CCTV 이름: [영동선] 이천
# 스트리밍 URL: http://cctvsec.ktict.co.kr/89/R6P11lgvsTT0pVXYv77AN37fTDdxi65XtShhRjGZY/ZLd9yFpzlz379B7y+dkoJV7adZaKUXhmS689FHBr7zAM5K0bOHFgYXpr8BQmtNfG4=
#
# CCTV 이름: [영동선] 신갈분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/90/Arl35J1YDPVSEbWXytuv4hpcC1E4ypIJd/LBZ3F4CgEQ5zAIVc0ZYfdX9tQuQfW6bDzglLS1a16l9cpmHV3ENUTjjwivW63KoDNoA+SQZ0o=
#
# CCTV 이름: [평택제천선] 안성분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/91/3PrmZ3nzy8LZwQJOfkFnTxJ2lfEVKOhfHdLvCs1YlxTSDUle2vgMHxFKuV8rzjzC4nuWIb7ywvo/cVK5sBdm4meeyoN4YkrtMJr/6Nwz2q0=
#
# CCTV 이름: [동해선] 구정1교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/94/vfIXlX5SWQQuLQ6TDIYJ1MTkqZL51QMknnyX42vL+XYEnxw97xuq5T1QqPdo7cjlcHD0A5xdnar/fJznG1XBMO+xqL4riWjAkH9MkyDkuyU=
#
# CCTV 이름: [동해선] 노동
# 스트리밍 URL: http://cctvsec.ktict.co.kr/98/EMSyyKkMLi7KRsoX9gN6wDR2LZ/DE3IsBVqohsUD0dJIFSMZjdN+MW1wiP8j5VgNCi72pvMo5Js+te7oeFHvmI9UPPj3OFapgAEpGKNxePc=
#
# CCTV 이름: [평택제천선] 송탄
# 스트리밍 URL: http://cctvsec.ktict.co.kr/112/UN4zgHnaS79gHqJcbk63EYSsNBUsIh71BMYMouje8vR7MB57jRPEGOBKVeqDqsqeUDTTG2pIk8nzvR4pJhVPm2pR9hEesBLZEIybBftKemY=
#
# CCTV 이름: [경부선] 안성분기점1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/114/4c4JL0c2l9rw8HFuZfcrpd7g/AVkq4DMTPhx44DZvbGXfp1KROYjwnx9UFZv8bRtuhaigzalfEb8EUVTnqDGtZzjYQi/sjMEpcCgHJyPFpk=
#
# CCTV 이름: [경부선] 안성
# 스트리밍 URL: http://cctvsec.ktict.co.kr/115/5HZGfCNQ+7dF8ijHImHzstfmz994MdLd0YK6hPgeoXZXtrcjH43DRU8lS/su/mYzWCspuUEadfRTw/O13Ql4CjdF8t+p8s8MSj9IExUraXA=
#
# CCTV 이름: [경부선] 망향휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/116/a/YXj8WCT/p6s7jbsghW/wVnSB6CVHiWqFZnV2Xx3+Vv5Tmc6WDQKIfIbeHH/RSh5iHXCJXLLGixrr+YWF4fN1lByBjB7L/+4jZn1I2BTm0=
#
# CCTV 이름: [경부선] 천안
# 스트리밍 URL: http://cctvsec.ktict.co.kr/117/289kMI1PR/XkuhvqMazfyegU/gZIlKAn446JJZ3fWDD5VKOrE1uraXmpFMCZJYhmwNId22O+rSoIKaY12jv5r+cCLcz/N5A77ILUvfzuMqw=
#
# CCTV 이름: [경부선] 천삼휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/118/rPkRSOMa6FH/Xv++0kU1bPay4glhAoNI1+eXc3EtIQUwcGaQ0cOUGaljt32axJt9bpJF+eFZKTYfmBRqgSYS6Kefnovkbf7juGv3aaRL4xg=
#
# CCTV 이름: [경부선] 목천
# 스트리밍 URL: http://cctvsec.ktict.co.kr/119/q7CjHqmPn9v+PNtsAWae0sJq2vWJD2VW5EwrOZTGrlsXRKng9oCmhJZQKwbdeG/9E2+uBGSv9q6B6uvXBn7Yj6bm+y11jtz+DyFn5mPvDBE=
#
# CCTV 이름: [경부선] 천안호두휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/120/Wk5vSQ0oj4/n8FsIYidgWIbA3Oi/ito0bo0Qqn07VTORvPToaAOwa23eiUTcL2GWGO1PaqOtcaOdVK+Rz4I0inFsG3YkjGINDijwhPMz8Iw=
#
# CCTV 이름: [경부선] 옥산휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/121/SAx73O0OGRVBoW5KPj0tQwR9K80/h56CKOAiOW/E3vkG3WPQLgKZVuzAVOV3BM7qgP9q0br2J6M4C9mkqDhCfrnbx8boRt5gxgDzsAd3Qf8=
#
# CCTV 이름: [동해선] 석교1교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/122/a/7KWLuYqAvT81ClGZKMnnjDluGSFsnm6Ti/FH8qa2gmWZc/XEWGq645ZoShPpdlcsj+gJLW31WQEzU03vdsG2MjonPg6SiwRz1j4fg1Nzo=
#
# CCTV 이름: [영동선] 여주휴게소(강릉) 출구
# 스트리밍 URL: http://cctvsec.ktict.co.kr/123//AgQTXKHPtF5VHPYFQFD11vAJyBjdNxzd/xd/jUr14FqjSqkLsjQwCPmlnbJxxk5nCOarMwTn4B93k5Qiic/C3bkFWQhII/MLjBatH4HrsA=
#
# CCTV 이름: [영동선] 상거리1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/124/7vpyy7FYWyf+ddACqzlo3XS3Z6L2QyW1zxWaJYoz6Y7mFAba7HBBFlTBsHH3Qdk3GzxoPnZfPHrUByu2JcdeeZFl9uTUFaUpU+wIfZaKV/o=
#
# CCTV 이름: [경부선] 회덕분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/125/0HezderbsNDjE57zaiBH7R868gmP+3BZ78YEg+gpokgaIzSMmELojFl9u6WuRwYIy8ZVRyUB85xRoejVaBswpiQWsiC8CtN8/5bQYKs9SWE=
#
# CCTV 이름: [영동선] 멱곡리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/126/kH08cLK/rnvV2yWSbcQG1zUIaRoUKqjZe14Syx0u7lbpQenw9FvrnpvZb0giGnMsYbcOIOjq4zS+ZUdc7T90MRSUPzET1o7k2/5I4Zc5yFk=
#
# CCTV 이름: [영동선] 섬강교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/127/OaQXAeJT/qBVGH7IC4LmAxaUgPGP5fFIiL1kM5jaOR9+dpCYYTgXlc9BugsYRoQHW+zfSboeHafexGzDFoQ7ae7yaZBqSN/C+N8fetXHy1o=
#
# CCTV 이름: [영동선] 동화리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/128/1sr2gHmVD+w5f+LDpfTOrbkKZQAple4TA3dFJoiNjwGea4Fpnk+9TsA7eA4UaPR2M2XPwEZiJf5l7+2xy4buxNomt4/+Gh0g8Ula7wRYbvM=
#
# CCTV 이름: [영동선] 장양리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/129/Ooegh4vqQJck2yCQk9Ad4TpupOTKzfdXhx53Epef5Tz/l3oPtWQp1J/dCAukt0R+60xMczApFeeTfKVT0DMk0kzt70iLsQEOE7G6rqi87UE=
#
# CCTV 이름: [영동선] 오원4교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/130/e2oe94qvPQjL/K/zDT7WY5Wm4+YmF96VL0Yusi8jyLAHH4a57k4lJA9bL6R2dNWSzENa3acxT/tio/V4L7uF2dbXOhD0scXUaupcthiGoCM=
#
# CCTV 이름: [영동선] 현천1교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/131/mlx8mRMLt/ESGmfvRwZbztbmEuYJJXT9KeD2kCCYLkRHXS14K1J2LKm7FJR/P8P9qdNUTnYtpyKoWdwmwmH4+t4iUaOWEoftcOJG8qd5WQQ=
#
# CCTV 이름: [영동선] 주천강교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/132/V7xwYfkVQ4CZnBQ7bTkstQvb4HjIvVMkOk1OHYrefadDJNEqmNO156H8xHZGax14oPACDDyByc36OYgj31gAnzytquK/035KaUH6mKIjqQU=
#
# CCTV 이름: [중앙선] 주산리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/133/pV3WAB1LHRMMBZrhghVZ0PJixk728CuAAlJXt44VAxLGbbkapJVgp8pzd6mtGV2DS+5sV1u0e6AHNSFEm4NW1KoE9NNM3RW9ZUbVvIwuEcA=
#
# CCTV 이름: [중앙선] 섬강교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/134/sD92jQKV7277wAZpecGRcxnL5jpACgVbeSGXnMuRDxKhmKfPGY03IG0kVBdX4e9XDLPrOYP77DesEpCsgeNBSdwlDvofNqADiL854crzaIM=
#
# CCTV 이름: [중앙선] 광격1교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/135/lt2Z4OKLsfb/sxQE/dPSc9MQjn4R3v/E2OrWbjmSGSRvWKgRV3YY1NQ07EzPR3v+BCtEg9yW4+ie6jwiwBt2CmwNllqgCRT97rlwD+lrxRg=
#
# CCTV 이름: [중앙선] 역전평교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/136/M+sZxBJEown4UV5mOB5I72B32Fpd5AinIDhOSXCHBzeIcWCrJKY49isjIDu2KktXxqCsrLCoZkkvlmFpcVumj6kglZF2fFsvQBXRYqEd5PM=
#
# CCTV 이름: [중앙선] 원창4교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/137/F5y+liwQD9gSwY7BOdIH8ISZKSA560BFNGseE7aimb/vJwwgx4xAZ9Vn2eERKaS57UTeQrxpoierR/g+xdLPlBD0YNuBiSsoBvdBAO18eos=
#
# CCTV 이름: [남해선] 죽평
# 스트리밍 URL: http://cctvsec.ktict.co.kr/138/qgS8D2sTbs0s6RStJFu/l41UI48ypjKbWTc7oGU595R8kWHWOo8CXizSgBL+gej3doNnXmeVn1UXLkRhtfzxTIcJ9jNGE5Bx51hdStrzVl0=
#
# CCTV 이름: [남해선] 지본교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/139/OInXDwon8nO0AMb8vCwIWLzVsx1ZgW4psfVXLUdEixrcxFhLpavPXjUu5pRfHzTQ+YXTunsqwzG4m6aj87WtKy7Alc2wqHQc+7ZYJvrR/Hg=
#
# CCTV 이름: [남해선] 구상
# 스트리밍 URL: http://cctvsec.ktict.co.kr/140/0U1cgQkOnUPnCtOffOXlz0Pp1o5RsvhpoXcjoK8wzEdj+khtC1AKNx3Q5fnkgdhnrRe69OI/eTepi1dxEAwdgrFrdr4P/lqi5eC53gnw5s8=
#
# CCTV 이름: [남해선] 청룡교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/141/oxKCJ7a5b2h1eJDwPNG2QZzg2179jksT/K7+WYLU1AY68ArYZ1XCMeH5LQBAAHG2WDe1YbtBtCTDJg7gi+a+rMgyAoqpZOQk8TjPqyq8sCM=
#
# CCTV 이름: [남해선] 원월교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/142/XYyOSv/7VhO8wnff231aUHhgGLRPBFk9ZJDsCiftbj4N82+jvpR3tylx3bKyzuCCLW1KyYN+B9MGIwEa3R4iKQ4Uj9n8OZckSHrYnqBy83s=
#
# CCTV 이름: [남해선] 신금
# 스트리밍 URL: http://cctvsec.ktict.co.kr/143/zYkHzGq7zxTZJYO70+gBrsguVIIDFZwnqxmn2oLYZzoDNvR4Mfc+ZfouN8GNAJRerfHKNbFeMXbpMwSW6O3gAQfzWbuYiOQ14Tc9drr8uUw=
#
# CCTV 이름: [남해선] 선소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/144/iI1dHuHgM0yDlWyM8TCpriWJcoqR7gDidVDxWhrMsn3Nfjh0uOp3+kVdbniztny7wzLwLUtnAVhZXLRbueEX3vot13h2D9lPW4WSJ2TrnH8=
#
# CCTV 이름: [남해선] 수남
# 스트리밍 URL: http://cctvsec.ktict.co.kr/145/OerXQmVHLIPIuaSAHp1ALXfYQSJzhj04d6TrRmNMwTUjkp3a36N7quSMw/o3GU7SEUb0tRUjQwDXnVFVhHkryC9qIMnDowVQ42Z5NbncWrc=
#
# CCTV 이름: [남해선] 초암산
# 스트리밍 URL: http://cctvsec.ktict.co.kr/146/2WO54JjvGyG3jKYOmABAdxDrNjjGLhtVo6T8SOgAV6ASQcnVpsKJkYS0M8ZGNSe8u57TLnRTBMLMRpZaFH5+CBLCfS/n/P79Pn6EkmlSdAM=
#
# CCTV 이름: [남해선] 마동교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/147/rzwDanQ2+kzZ+o1sMg7xy+dk0u7O+37Evp4mJmN03DPP5HWlGWQAyvulwyHthoWEwhm2w92bS+g01WYt6RmkcXAnhXYLovYIlsHEquD4wWs=
#
# CCTV 이름: [중부선] 신월천교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/155/vmQCuB4XgUE4/3gg4Mn2U1nwqqQrcwqTF/93seRNurlhWkWLyun870C2y6NhGpWsevPSjhBSHonhdSww0kG6xoBUvOIbGoj+feEYYFSKYFw=
#
# CCTV 이름: [중부선] 후안2교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/156/ILWQgyR6hueMGYE6l8aINi3az+w7HROG0r89gUIljtItbZU1rxDdRru6uZ/bcYFIi7xxMVLK7RWhBjtbAiLjZEq6vR4dezQtl5joNjqZAME=
#
# CCTV 이름: [중부선] 모가 졸음쉼터
# 스트리밍 URL: http://cctvsec.ktict.co.kr/157/AJB8VCmZZNHeNQeXrrPxtcZlS8Z8fi7P4nX7cBn4Ydl2cbHZORTG5MQQGkOZ+oqzQvzeByJacZeQQFfztaDOty4WYM3Yo4B4Mhj/hnyWy5s=
#
# CCTV 이름: [중부선] 낙타고개2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/158/+6ECeG7keiFajdd0bII9OeKsPW5rHYsKUlHLzxZp7TQAcwb1kC9QBqY8hLAJeXSWkucN3grjPmNcHdyFtl07ztqHNtDGGdJVFe+gblkjVdE=
#
# CCTV 이름: [중부선] 용면
# 스트리밍 URL: http://cctvsec.ktict.co.kr/159/fGI6yJ32lH2tPUJtVSdreyzmmDPHFUAWp5He4AVVio4gCKMTLK2iyZWXg4KHJ2F/xuzCw/+Yi/Ni35GcsX5ILGMeUP58FCW1tcZlkj2ktgs=
#
# CCTV 이름: [중부선] 용면교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/160/noiG8j9SOGAi0QX43Dv49aEphFsySPmAL17oaQZ7bWWYn1LonPnM0bjr0lgzcLYIMkDahPVkmi7OUtrErZlATGUzz/5M6FWYeDxYPJkO2XY=
#
# CCTV 이름: [중부선] 낙타고개1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/161/lVq1VVekjyz6hbS+N1MLupym5CCtD35CxB+JZjkBl/n0ORTzYrMu72ivUsbrKjxorBaKoZbiEcPGbNC6MSw6ZalpcI4YXQpL0GUU8Rcw5TM=
#
# CCTV 이름: [중부선] 장암
# 스트리밍 URL: http://cctvsec.ktict.co.kr/163/toZAYEL8CoAoDROTQMT2ptW0XVbvfl0df2t0pRwXo2/eprb3GJ9qGiN5VzSJeSYPvgl5X2mk3iBOVpo5hwV6huy2GftEkZu9UryydP8V1IY=
#
# CCTV 이름: [평택제천선] 서안성
# 스트리밍 URL: http://cctvsec.ktict.co.kr/165/wELzXZb+FquaB3TUJALb40X4ajJnCDZu/zGgduBv4RhgVqQEpWGgXRaolJHOqrjIoRNDs0EneSfmL9GxIsKsZPbI+H0o8baMAjBNOkHz+P4=
#
# CCTV 이름: [평택제천선] 반제터널
# 스트리밍 URL: http://cctvsec.ktict.co.kr/166/0SNAyoSH0eIFAknUGnh/jmAmBeV9x5IKgTeY2UNKSHf9wz7FdgErM6X+qWoUNKHl/UwcGkmhmBiEE914DaVDC3S7z5yurXxQFUh3mvsPEKA=
#
# CCTV 이름: [평택제천선] 공도교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/167/xo5lHHMySo66/jiwsERhE9AktWTxpeq8S9/muzFQQDXlXTlaxMk8sej8MbPZm5N0SLfRDKqEJDjQo2FbeeltzBGY3iFYAb2hCEszS7hpe+0=
#
# CCTV 이름: [평택제천선] 양기3교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/168/MKnaXE84ejvqauo+Kd1cqk0ti2Xm5TXRyCnmcZ9loKitw0kRPxOmQtYH/s2Vv95jshdyYzRnhSOLLWUnZPmviFqd2MKQN6ubU3WWnoIvXA0=
#
# CCTV 이름: [평택제천선] 안성천교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/169/NjVeISnT/242/BdS9zIUZHi7ldJ/cyQha/dNuVSqBQEwKGnYG1Nev7BqPKlLiZR4hsNoHfU9Lf8quXYudZHtBR17FB5VCEGyW+KJBdcGGt4=
#
# CCTV 이름: [평택제천선] 남안성
# 스트리밍 URL: http://cctvsec.ktict.co.kr/170/wxTe2q+8Wk2ZG2gh0HzzfZCIONy0SJkvWy+8GWcucjReUq5VHc7goM69BFLTqWqXwJzFuS/I9hxOnhG8nopPZ1NZ9n3ZwsJR8Y9UirSrdQI=
#
# CCTV 이름: [순천완주선] 삼청
# 스트리밍 URL: http://cctvsec.ktict.co.kr/171/xQSEeZapXPj72yuXPNyV8gequ3Y7ysM0E9mZuKDvUicd5Tg8DO2gMrmE0FVubm9R5sosqZHOyHReD3H4HpHzhJ0wiI7mMzovkgTLdf2BDDo=
#
# CCTV 이름: [호남선] 익산
# 스트리밍 URL: http://cctvsec.ktict.co.kr/173/HUuarAnYTOSzbmqELPXQqy6lN107tvAgKm9iCkx+phj4tcHAuV74q+z890l8EnM/d510JoVRWBG2y1WXALVk5mxEZTZPv2xKxRVn67Yoro4=
#
# CCTV 이름: [호남선] 곡성
# 스트리밍 URL: http://cctvsec.ktict.co.kr/174/fxkojPBDSwqw339d8YmMi7vGTcfJxNQzY9nb0x9+R0YBIqgQ8yBtWI2EcAufgVbwDnhQeFTJ2kYHdsGR5hEm1JtiaHoO+FKI7qMcE8dcnio=
#
# CCTV 이름: [호남선] 논산분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/175/NgM//d5dxsX+C6ZI7KlVx6TWHxSxURIDjl0W68ImnJurb22U9APHNQ8lsRf7Wp50ADi9PV/1bwyOZBveu339yxgO2cHf5ugQnzqcaLAm2Yw=
#
# CCTV 이름: [호남선] 여산휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/176/43raPaJogkHe+TQ52f8fw+d9rb8I5aOA2DTlJzuKB/7LHLUXRreywPzV1hdHqj2gNI0DAoOOpgU8NELOf2ALQ7b00jM/pZWQXqrJbzfTnu4=
#
# CCTV 이름: [호남선] 곡성휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/178/bfvQ+N/pmXKJXw6v75WnhfUvObKjmz/m+c4P4uvE3vNULhAxHAkHt4OOiDHVyADzN+0r+47LHB/yoqqGLfuj08EYKGuqgjUsVQYLs+5cY4U=
#
# CCTV 이름: [호남선] 신성
# 스트리밍 URL: http://cctvsec.ktict.co.kr/200/Lov2/5FqsntKz/Ru1fjthq9AjwF7Z868+m/0xbVCLV7+NGlPBGaZuUZmDPCGoLzJ36rS1t58d/vfraHhFgSz+tJdJ6IawGezWXK1+KZl/gQ=
#
# CCTV 이름: [호남선] 명강교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/201/uXx/2dijtVDNGXH5LZIdpQvPV3ed6nH4s4Uo9LzO4CawNbCePqziarpHWoSg6nxlWvptwORz6tLCdGMC3Hk6yI8L7MF7iJek+dYEvZt3xek=
#
# CCTV 이름: [경부선] 안심
# 스트리밍 URL: http://cctvsec.ktict.co.kr/209/TfVOer3PTbPtjFlxtDbFIOcpaJORH1iZBDIx4BeKrewGa8ueKp9n8scEwsLd3SWNQ1lVq0jEcjzvWa9fkLwE1N0dsftT3kMNFFDlZcO8xCU=
#
# CCTV 이름: [경부선] 대림육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/210/FACenGKE50Vhn9rIjBpJ3jEqbsOT29fKb+mVa5URIYawr9Iqp0wzWvuXx6DrpLNEMS8CV5hPC/efZ1oERjwYO2fLqK5xfKhhYHlHpQMbfpM=
#
# CCTV 이름: [경부선] 금호2교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/211/w0nBxynT4Fh4zJGM/u9yE0I5CMwtB7zsItTOjNT8nH3DMVUtpdqRo529dnoeV65MYtwloDKjcmaNPBofNcvvUVJssEAE9fxE6/ZGZrP7ykg=
#
# CCTV 이름: [경부선] 석적교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/212/U4qyHsHs7V6fw8urEeShnzazzvJaF4iBBS8GJdMkmdMGVRN1jt0EMPkQJFpo1RFw32Ri2XkrgCELkC4FAXfBjnqUz0HbC73up1e74yiTQpM=
#
# CCTV 이름: [경부선] 사곡
# 스트리밍 URL: http://cctvsec.ktict.co.kr/213/JP2AEPD/5So2Cpo9NbfpwwtZ0zEogiwPT3TMtTBJP/iySnBJb1F7FApIyAenTF57JYzj2thaCRO6TFYM4ZGCDEeayRSidnYHwHpUr0Z9u64=
#
# CCTV 이름: [익산포항선] 박사천교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/214/5NfGzSR+bhQcTN3QNoXIrJPkIwifTML2nNJFQu/Jv7Q5oUVOvXE3C/tLUBWQXQ/1T8N3rQwpFEiU8RAX2e2HMOAnukcsm/mvPSAs0ghULk8=
#
# CCTV 이름: [익산포항선] 보성교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/215/qdxB69KGItSxdEDgDPvYTRlagxSVBsF6LLwo6BmIgpIz4LPqd57vIBQyaVjuBFL6d/MWdk61TbxO8SOHo00l1vDul+KW7PuE3Z6kKYCT9z8=
#
# CCTV 이름: [중부내륙선] 삼대2교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/216/ahkvCHxae6epUXyrV6ZleFjvp21lMJUS8/7yXVuKcefGOiDLtg8D1HrSj95BoHRG1V8FUXOqueI2f1gVgv8jNDVd5z9rCX2e5V96aIJK3Y4=
#
# CCTV 이름: [중부내륙선] 성산
# 스트리밍 URL: http://cctvsec.ktict.co.kr/223/PAXsKDfCMK1swAOus9/Br6VGwsLZBZ50uf6fdJ6DrOBooy01fz12GbaC/ZO6fJwp27/PSpfC3aaztQC+A9HARNr5jrCxQCaXcjXZb1QmjsU=
#
# CCTV 이름: [중부내륙선] 별티
# 스트리밍 URL: http://cctvsec.ktict.co.kr/247/ldnQP7xLOKGpnYRl60qsVk6pRj3JA499niel/CwKrgOFYtZ4ryo8jTS6tPkeslf12bvBn/Exa8S6SDVbbwTTVEVmkcvtIf/fAetzr2s2uzA=
#
# CCTV 이름: [중부내륙선] 성산2교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/248/G/RDF0BFeODEqEQrk+x8AQ9BtuaXngwrfxB52HKBHZvd9kY2lPDsLDa7B73jZlNRgUKIiioThi1+VzZ4OVMUPERgbHmfu98bMTLrK6D6P4k=
#
# CCTV 이름: [중부내륙지선] 용산2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/251/AavLFy5q+M4DlRkJqNyHzpD1disPkPLjf34hGGaS5tJKh96Q0hmzhb4nI0x4bkpVx5OiRUTrRuVsVoQf9hEEERC4DN3wMCL7FtLbi2BWiiw=
#
# CCTV 이름: [중부내륙지선] 서대구2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/252/8BG8kKUEWoiGVM82z26crCjihoD3MivQaQqti4uU0RO17zYZyUMh0Ey82tErlUEuUxrA7iNT1Zw6UEgDvA2zbwEuddfFJBJM7bvGwJK3yBc=
#
# CCTV 이름: [중앙선] 읍내터널
# 스트리밍 URL: http://cctvsec.ktict.co.kr/256/NFCGmF8hi9qzEvInWO8QJdHwcQzcQ/Me7dzYsfOVDfZWPR856AupIAy6ETbdwWT3wSVoZ8nroFR53vPy9Yl+2wj3NiXrLueQOEV63kLxL2Q=
#
# CCTV 이름: [중앙선] 수서2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/258/wcdZpXtaDZD2RTB1MGrrF/RyDxVyzpo9Ik9mw3eexK+/9oTzuYi3uz5DDShihA/62ks3NeazV8G0eWwUBidDj4aA3ZsdPwMko1isYomU1QI=
#
# CCTV 이름: [중앙선] 군위2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/259/KOb1GWM8aEpYiowIQHD0olrOECb9+dgTbHZMCULuLrW4x0zZpOidGmJ6+5aQqgKP7XZPpLBZAs6dLXPOJqXEeU+KZsYS1yNe2zvqahcDvd4=
#
# CCTV 이름: [대전남부선] 구봉
# 스트리밍 URL: http://cctvsec.ktict.co.kr/260/JIsCoxyteMZZKIxkFokrQH8Eg0SpTabFIq2qmF9C1Qqie/yayh0Uw7ufkkhiTxmgQ2cgWB0V2gJr/55cPV7TteB4rgWqKXYT5iwwlcxLH08=
#
# CCTV 이름: [중부내륙지선] 본리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/266/kmtmNpYyDJaS+ZZmrVbNBtL56jzpi1Htr16jh36Zsf1AhChvp6fftSZ2fjrFegZnWb6ezMI0d0EnTikgVdL36+9tr/DTvqxV5u7DUEzWDbg=
#
# CCTV 이름: [통영대전선] 동달
# 스트리밍 URL: http://cctvsec.ktict.co.kr/267/gyIfijT5sAHxDpKd46at6kri+4u+a9RDWGsZCxQb9vSrKFD7L7bTkMkkm/TiLnqi3/i7W1dVIHxaOe4r2nOIn1I1bN/bkY+FLKizkil1t4w=
#
# CCTV 이름: [통영대전선] 외송
# 스트리밍 URL: http://cctvsec.ktict.co.kr/268/DsD/seclsSVxk59c91KLKVuihUM8n3ddgYvZiC3UgCkFiqxkl/un71plsxFwW5v7Vy2GBABwN/9s5M0Iu2tHMrnFR4zWg5P2xZOs2NYLHHs=
#
# CCTV 이름: [통영대전선] 송계
# 스트리밍 URL: http://cctvsec.ktict.co.kr/269/QY83nrxuDIbwBnqhzmZlGiRfj7mf1HLUNi/PmWAzA1uMB9irVUtYlH7jm1wzp2RGIlrXZcLkeKSsbGXtoStsPDjBfDMbdJxmYxBJ1w2Jw0Y=
#
# CCTV 이름: [중부선] 초월1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/294/roMWFL5E39TRBSxxljte8sPS3UbpoGoHYey6JDqsObwyYNAlmpMwyEUG7a2QohFYmwCz8iWlyERUB72SOQRgI4BCitSbWlkPyNwz2N5rSuw=
#
# CCTV 이름: [평택제천선] 청룡교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/295/jRoLCPjAu8EH0xhvf6NbKpJhRn0pHYb3e/zAaMEMf0dGKGrnGCHuPLV6yuYH5Q+Fl4+wfDCoL5Gflm7gbYbfVj1t88S1xQm6kASj6+yCfmg=
#
# CCTV 이름: [중앙선] 신림교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/296/GFaNfTXs0XrRcZbeqICHy/yK8uHHeqr5Mg8jcH1nz7crrt/EwE7jfDTzqlSv1BQ4VKuxryiwHZsgk9wVNOj+ElW++QGjjFnzVCTz5XdKRxs=
#
# CCTV 이름: [광주대구선] 살피재터널(외부대구)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/297/GH/XVSPqif5YKYOZ6HMvdvcomu5ewJ9aeJ5Jmea7vV1IDQSe7dwpotijT5Wyi2pNBAp3RQGFn+ogHkP04Au+JlrObS21jPYPLrslNAlebxY=
#
# CCTV 이름: [광주대구선] 살피재터널(외부광주)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/298/lTSFcYf4exsW2kfrbIHvNUrSrmetDpM9FbDqDPnhjr2Ef1xQJ3WbTbRzpTg6k8MJ64CPzXIQqYc9pVv1DKt50/LFhLgMk7LdDPqT9Rk3gdo=
#
# CCTV 이름: [광주대구선] 야로3터널(외부대구)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/299/KNPex3gzD1VMNuel5PKtmzLoejod0jCT5sYGF1SIkpI31mXgZ22z+B0ci30Aywdw1yb0TAa7WmMCGDofuur14UPk1LXp0iuqOqZa0aDd9n4=
#
# CCTV 이름: [광주대구선] 쌍림터널(외부광주)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/300/xldy/A8uS7+zjpz0qHkRYuN70/mk5jc/26wKl59elH6tcZjkVUGokpJEZ/cAKgVEMjIz07btVAOfefX+d9t0+y7vp8HskOkTIhIc2lyUKAU=
#
# CCTV 이름: [경부선] 평사휴게소(부산)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/303/qQjCp5bQBBB3hamz26G0SflPHVRgkM46avWCU2XHgjtIgvc9wXlc117T1+VQYz5zpdyDtUVZ0H8EtKFhD2Zy3L2HODHmxnsFNlFPlj8+TiY=
#
# CCTV 이름: [경부선] 추풍령휴게소(서울)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/304/dNCtK6yWP4UhtC4Tl1gtrSDUOizJqajycE6QfJUV1foMp3VPeRyi49KZWLQo2NEa0V5E2xGQWXoU+y0uWryebPEWJBSk/ApqSvpxWa3Ag+Y=
#
# CCTV 이름: [경부선] 옥천1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/305/2NL7un/IjXuAkWrY7w3l4RGKxIXmrso7EUX44XGJ/IekOhZn1X+mp9GbrJs1Ljz4/noldzxuNFsvkCP/3PtiiBjxl8VcOy7qTIPLG2gUtks=
#
# CCTV 이름: [경부선] 법동
# 스트리밍 URL: http://cctvsec.ktict.co.kr/306/frPZye15yAeN/KRkRrZl/3VPc1G+nbPQ1TrjXB9Q6112EJgrlCCSgh0tyowQtfGA2YjjqBBETK1uWiguYVWPatU3VSbbWq8KCpN+3fwErLE=
#
# CCTV 이름: [경부선] 읍내
# 스트리밍 URL: http://cctvsec.ktict.co.kr/307/RBlHw3cx4tWvjGCzCu5cW/wr+H+fHkeBLEj7xyNr6BbW3Isf38aa1ofZuYPdECfUvT+0wKCjDa0tujnFTs/AvJj6PcEXQUU46oEOVUo+N8Q=
#
# CCTV 이름: [경부선] 회덕분기점(고정)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/308/eJyP14ns4S7Fmdc+HdDAofEOAFgFsGaNQTcvS/cdgLY7tbyUg+9KUdhqZDQtDRo2ekVdZJ8cKRakychpwJTssnIw4vR/s+I9dYWnDlejitY=
#
# CCTV 이름: [경부선] 덕암
# 스트리밍 URL: http://cctvsec.ktict.co.kr/309/MewcPmSSChL/+jsiK5FfPy9a9AaqJZ2d9CJ8wzZZN6AKZFMzubXzQiAWY5IxjLZwmG8OTi3tj8l1iOapGQ3lotBvqFAaDS+k6xF12kNfgPg=
#
# CCTV 이름: [경부선] 남청주육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/310/DEqW5DKE54S+GzU8Vbi9LDf2KS0Bj+JC2rvv/VV1nEGrzv2tRg8RghSLoWeZ1eeOQcQCLsDZVjhNjHQGW0mBDLcLQl9yIuE4v1v5Thd6Akk=
#
# CCTV 이름: [경부선] 청주분기점(고정)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/311/fc97p9Ra4qLrCrhBixtDxpD0mvG30AMEByt5pvaBbXHwDanKqkB+GTMyGwgcn4Qyg0P9qvNJZvCIY+8H1FDtM0/zQCsEZ98/cB1xiKlpIgM=
#
# CCTV 이름: [경부선] 가마육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/312/FSafAJ+YGxV9JRSlyQs+/xSxAngUYWQObdMSE3TlmdIzD1YJoxDYFj5GWWU8LMQNz1jt6jbClAclNf3LxJNJLXTyfDbO7r7102pH6K5NI1c=
#
# CCTV 이름: [경부선] 금계
# 스트리밍 URL: http://cctvsec.ktict.co.kr/313/9q9sJ1KbzGauCzkIpUPOiqQUzJpwXrwYI4FKAtIIuWz7cs+b35lkhwRcjnB9hw00bx0qc8+LlC+NpmMKU1rMK8TtYKJFgyDjgccM7MRktWI=
#
# CCTV 이름: [경부선] 목천(고정)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/314/padGgYOCdIhTJkEZggf1AhJG25FDhzcCMchG4aB6+1Narsg4ecCoRkX4GJv08YwI5pYgxvlfKJWtVWr9wqxlV6sqB4c4AcDlm2c4K83IkP0=
#
# CCTV 이름: [경부선] 신계
# 스트리밍 URL: http://cctvsec.ktict.co.kr/315/cX/FKVC/jEKLaokUFxQyTZS7VEpAVkhHImybM4iNbcdsssqeshCr8DI4j177E46V432ZmAaj0u+aOTbqO0Yy5jTNv/dlk2RL20EBiYjQ1xo=
#
# CCTV 이름: [경부선] 구성2교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/316/vLysVYngGpevHsx9QU964cYhpr+L1A7bY9UWz6xrEA9hil+wLjUe08ShNUigZZozekDUKC6ezhKTCawDTj6Wtmr3IFJ3K4PZ7vg6SGa83Eo=
#
# CCTV 이름: [경부선] 하암육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/317/l2Ug1HZBOdyVp92DZuFXhz44dOu0F+qNrQSfq70rTPkpRW+vHKtqtuARNGUnG+v9rHWOKuf+NblucTH1KniCQJknr27Qoy4ftHl4Ikwx4jU=
#
# CCTV 이름: [경부선] 안서철육교(고정)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/318/yxHM9zW2Fh8n48CTD2KnoMFXYxi/fRn0JEeRF+LJU1RnkK+rdded9BAUZHEYRIZeH6Y3OC5lyB/92HhUKLH0ilhbqPaxfAm35Nk6AjDPMVE=
#
# CCTV 이름: [경부선] 서울영업소-광장
# 스트리밍 URL: http://cctvsec.ktict.co.kr/319/4saM267rCWTwKgHjSnfThqfGhvCPWhbphxYntdfD3FQilN1QLhnLz1FU79LO2beyKA6WQvj5sckE3i8eAfI+tJVt3E6OaXnt0XaibuDQiV0=
#
# CCTV 이름: [남해선] 덕천
# 스트리밍 URL: http://cctvsec.ktict.co.kr/322/2Jy8Hc9AEr7Y/BZIEEa/sor8LPRa5q3QBMUyReagwwWjjTnQ4nPuqqIKpv+/u+2wEUt8UCy8c/FWUhn/ngksNdmYyK2dpK4KRlvY41OCf64=
#
# CCTV 이름: [남해선] 명교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/323/6GgoZuHgV2gG4krWRLCxtmJyGesGt97tIuVOPQd8PrBF43TjuaH8YvIJ/iDAlHHR7aION52u49VshiWNrST2NKVUkY//6zS2dGI1/BVe0tk=
#
# CCTV 이름: [남해선] 백련
# 스트리밍 URL: http://cctvsec.ktict.co.kr/324/VHQLFuZqCSiFY2SSXg4nsqaQRQ3h8ojnWE151wMmIa3Hz/jB0G5P/bh1uVHzoU+YsXa029Mq12KgL6NjB9brYazXCZl539L9tRthTfydCxU=
#
# CCTV 이름: [남해선] 금곡
# 스트리밍 URL: http://cctvsec.ktict.co.kr/325/8mHxJQr00eD+MX8ZEWI7MXTojTe9Gl50UPZm/nCt3Qeoumf32QF2PFrDHa8jqq98UIEpJ7vec4XVVUIXQpP+iVddBd4gx+AvN3i3KslGbKk=
#
# CCTV 이름: [남해선] 청담
# 스트리밍 URL: http://cctvsec.ktict.co.kr/326/HbZGHrUzg+lOsbyrSSKMEl7M8Hz7KLJtYJOKfsFH6IX0P9LKkt4hm1Xo5/r5meTbV4Uo60UljcApV4rfkpUpOmiCygnVSZa46pRvI+AxmWc=
#
# CCTV 이름: [남해선] 박곡
# 스트리밍 URL: http://cctvsec.ktict.co.kr/327/2gjFwe19J+K8UkJLkXgLFEyE1ToGK8fd5Y0B3NonbHwZP82XFl7QT1z1M6puPO/94b6dZaVT0b/K+1twTMm3bf5c8+W4j2KoqKevy7IUR/U=
#
# CCTV 이름: [남해선] 용정
# 스트리밍 URL: http://cctvsec.ktict.co.kr/328/H7JJs2abUMlmAatNu/os8Sx6DQmPO1jhXSRSd1ZD93rqHtAWxsyC637v5WFe3gosftgYjbBFbEKhTzIxQ2MtT+JkCf7yyY9bJ0d8eAdZ9tA=
#
# CCTV 이름: [남해선] [부산]함안2터널(부산외부)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/329/4QGZ2OZ+m/IK0/87fT7m0WoS8f+nN4HnxQNm/4tXxWFE/6uxrbR/DaGzPLVLEiBP2IhyuJI3/vWt1k9IZnxwstRDcSqyo42ujCHUfrMmNG0=
#
# CCTV 이름: [남해선] 양동
# 스트리밍 URL: http://cctvsec.ktict.co.kr/330/7X5prkhX1Le14wOzvKR0fer+CIs5Kt7wvMmgkd9+S7pg41Yt+ytk//xv9evnwUIQLNg/UweCTXlWNPr076CRuOnlIijs+OzZGkLwStwe6GU=
#
# CCTV 이름: [남해1지선] 용담1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/333/v/XI58q3CUHx1OVOlqIUOigNuwYQf0a7eCXpkGSRbt91xcWzgmwYVDQ3p0U6kUoO+2iA+VAzfb1QsWYai8oSbosH2REj6e6XtFux3+mZ7EI=
#
# CCTV 이름: [남해1지선] 용담2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/334/wpf42sFx8tZ2eZIxx4Ylxlttz4I6+gn4CrNFdRUNdheY85r0b0ypJvYLvtKiWI2ZRlQpQHfmkFH55OGV8wRhKnBMjfXqgEJNGwGEPilRB68=
#
# CCTV 이름: [당진대전선] 월미
# 스트리밍 URL: http://cctvsec.ktict.co.kr/339/yWTW/Y0J8o8WX0rlZLuLx3BRrE5lLrcs9F+54Z4hQVz+o2b2ZZTbCxiXwMnYQE4/fb4KplnNm0qcRmyFn+z3KlHGz3VjCqkp+njst7XHCqk=
#
# CCTV 이름: [당진대전선] 영곡2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/340/iKV8jkjlRNtLvMtaI3wywKS2CSD5E82zr9ra4XOiyRieORHMEZ6B38Lhn1qT4928Z5bZy2WnuUFP9rGZorh5bRMbRJiqqslmEXiIFCO/arI=
#
# CCTV 이름: [당진대전선] 용담
# 스트리밍 URL: http://cctvsec.ktict.co.kr/341/JAWbz04ZPMZRKM9B6tjHNmrQ6kvT6cERMBC/h99csqBruGFeA5dcupiFCqABRSR+MUvTMTrYTTPtNYa2oPL2lJNyie8Rejv94zWXgFbFkPE=
#
# CCTV 이름: [대전남부선] [서대전]구봉터널(서대전 외부)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/342/3PKKGggqSVIFQa/EA88PTD4J0vgx7qUKIAoFkl1jCfiZiZPsYFMmNB56Wey26eVQR4a5fPGOErZuyjY3NF2PSZp9zCoZDAcCwXV5ZNxJmHI=
#
# CCTV 이름: [대전남부선] [산내]안영1터널(산내 외부)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/343/uCJvIOlWhl/4W4QfglAL2cwLwGcYtM+wPGdF00qxZqtnAdp7zCa578pHGgu6zk/HF9ID2ckiAwIX3rIFgyEsZDzd/3QlhOxtykUpQiYy3eY=
#
# CCTV 이름: [서울양양선] 서면6터널(양양외부1)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/386/7emKOKM16K5WBhS4rBAgLks747Gz9K3XaB95rlxvpSvNsIxf6Jt+lpZ9uTp6ponW02czo9z+19xvNTgSSjOAjvuxKmACCkFOcn7aWTyduHE=
#
# CCTV 이름: [영동선] 삽교 졸음쉼터
# 스트리밍 URL: http://cctvsec.ktict.co.kr/496/E64v+X7CVb2eBmQMBctvLkUsD2zfZwB2p1OIE/KNMZHiEYt1SxvSD/E1fBbpa+I1/vy1UJ+B2uly1JggDHOIIxxdr7RyYTRjyQ+O3kYJNtU=
#
# CCTV 이름: [익산포항선] 명덕1교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/498/InynJFrRhCg9fSXSwwpR4B+1yLI2Q9wK3ASEjzXsH7YafpmGNy84Vc5dUvoEBrs1ZXH6uWX+zSZqX4OY7zg+VXTZzxrPZIQoj7cZmYIY0HI=
#
# CCTV 이름: [익산포항선] 단양1교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/499/hNB2o/+7dO1DFXeKyqX0EJOresiv2NWe8gh1OdcMUOuWEvoYSHAmYb8YdsUqimMAWimFdixtiBMW4XeaQ0C7o75B3kyyGjxwfv3Zw78Fq9Y=
#
# CCTV 이름: [중부내륙선] 오곡
# 스트리밍 URL: http://cctvsec.ktict.co.kr/500/wlo+bjsux9uSLc25+QkLyQngaeoitdiXhvAC8aMugO0JLHXShHjvWPVXZzwVcbVCZQpZqdV9LN3mDewkERYE+mJrlQQOWQq+UBm9hnLBmJw=
#
# CCTV 이름: [경부선] 안성휴게소(부산)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/502/WYQ4txiqw7pKqGx0TXG+9GmotcIOviXXP7uuKkXUkAJ3kTbi8MlsIJrDaQLnN3U8ltjD07DdxI9vXctjYyKbvHcVdsrKyozoNJjraAWu4bg=
#
# CCTV 이름: [경부선] 기흥휴게소(부산)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/503/Qi4conD3xqCJk6KcnNG5YRam1GT3XuEmPvNc4PlgDL6i//23PXivjDBCvlbkEPhdNNKnVv58YfFSJQVDNq58DGHalm1VQ2Cxy3XDXv5v+14=
#
# CCTV 이름: [경부선] 진위천교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/507/2ERiKQ1jryAuuRgEkZj5s3U/lhuSeet4P9jK63ViO6e9LyugyL6eGzLdwnu0uPXHWK6gdByPCqmqNZ93VEJyqNEjCUpQvyhaB4cFzF69HXE=
#
# CCTV 이름: [경부선] 남사정류장
# 스트리밍 URL: http://cctvsec.ktict.co.kr/509/qxCntuX2lqBby3/12CNRO26Uc1BSuQGhYR0Xe+JHJ8xhvyg51L/cO5pe+B1PSHLengtsmcYYmyAY97kD1uLwCSUhpgVtZ/CaE9LmKERnuik=
#
# CCTV 이름: [경부선] 입장거봉포도휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/510/K9kjZ7DLCaBaxB/Trt5DAio7s+cYNKAe2c0uUaGjKgf6xCvXEb05iAnPDQLy1e1x0ZKxp7RYs5+truiHW3GztLbh5RCYAto+0ZH5SfliJNU=
#
# CCTV 이름: [경부선] 용정교_경부선
# 스트리밍 URL: http://cctvsec.ktict.co.kr/511/msekI9OZbPtIdjQsp6JNFc33B36d8OF5e5FEbmbf09zCO9LKVDgoJHWB7NDl3fFFgiwkMjp6nijz9QFhGWbd9V5yCzHtgCpqY59sRVqDiT8=
#
# CCTV 이름: [경부선] 천안분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/512/oZDTNJ9qhtn0pktOzWayvxUb1xZfk8/lcX9Dwtrj/em+o/iy05i9Bb6KEfVwRUXhRehwgAxf/Khhxfx/kwsVJeUknyNriu7TV8rTLATqE6g=
#
# CCTV 이름: [경부선] 공세육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/515/kEE+mtrDxr27eG/897cTDq+EYdV5prowZuhVgsDaEVyWWwBiddPefCaCMx5pbEB1Mc+0LQtKqFRxzZjeLQJ/++3Z156i743Rn74m7rBL2gw=
#
# CCTV 이름: [경부선] 금곡교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/516/ZuIzn8zGWVFin1DMWSShKP1bg89/knKGzMABhyBs95ZXJQi6kOPAvnGZdn6b1777G+Aj7EAipdw/FLfVq92SYVieg9An0RZD6ChCMCUoFOQ=
#
# CCTV 이름: [남해선] 함안고개
# 스트리밍 URL: http://cctvsec.ktict.co.kr/522/8Rw4gKGsBMES2jhpo2Ewrcg2pA5jvQTZXyCQs8UVhp8zpgyEFu+paFnkNfMLqtW8L7WHNFxdjqGBcZwYWRH41rjtwnSa2k3d508FJ60lp6c=
#
# CCTV 이름: [남해선] 함안
# 스트리밍 URL: http://cctvsec.ktict.co.kr/523/UzlhgzTIMLDhXjwyPW5lQT1eZlt6guD1KEadxXrooQlWyYJ3lzqIh38Mv4d1MBNePEPFda8aE7Sjgfgrc/nRt4ZtMyp/D9vwcypfcrI1xlA=
#
# CCTV 이름: [남해선] 산인분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/526/IKuZBdOiGceSAv8NsUrX7vl2YYhLgE6w+7SxbrOzLxPyrzY2HBYvNkug+C2kQUds7vm+KHe6RxLS3boeNELspVbEBBmfV6nIkShf7TnZ/g8=
#
# CCTV 이름: [수도권제1순환선] 성남삼평교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/538/1L9kVxHVFgW+fT0xlrQAHa1knmozTvhOlVFKst5QJjXbXQUA68d28889ni4JHcj9GXYW0+uY5vGAkNa7WSjY2QfP0WLfw3Ud4nvZxVlpthM=
#
# CCTV 이름: [수도권제1순환선] 거여고가교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/539/mDcRLNJeyok00HzlLS2McHd8BjLqUPXyHH76nIfEE9gPX1vpqH5FOYUWnSHkcldJgXIHk6oCilr3r7iyJYm/aUhGCjDZNdMszu+HEZIm7OY=
#
# CCTV 이름: [수도권제1순환선] 복정교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/540/uaM6frwSTqqAbuZ03oi0BKh0Gl9V+t6s2r0wKg70UElrhoFdwkppIHVukpVYBr0AauNjyoX05mmLDUZOIBURWCQkMu5eF3faLjATIGQCBtk=
#
# CCTV 이름: [영동선] 강천터널
# 스트리밍 URL: http://cctvsec.ktict.co.kr/561/s8Y95/U9mCy6s2ziPgFYnVWeq+eP3Pz7VRSa01uIM3ROhfXaObxFKLyH25J1slouo6P8+UuOFPkJjHZl3CHM1lgGUmzqJS9pEOyPslX8UsE=
#
# CCTV 이름: [영동선] 문막
# 스트리밍 URL: http://cctvsec.ktict.co.kr/562/LKugLgutvTcYvZ9ayCnFmzo7xKKTQdx3YqoZoUD2qykklg7ZZYq0ttvELx6Vhe9Cye6Zxc5OjKGR5JZqK2VX6k057xE5fHp7fZFE7sxzECg=
#
# CCTV 이름: [영동선] 신갈분기점2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/569/n3rKW6EjiULauSYXiCBk8Qbx6wDaDI3ms3qaELkD47N1fTaEGpsZD78iIirxafsRi8YNt8+CLXRaUld0ZWjaPV+IFi8Thdk7xQ0yAyAUHFI=
#
# CCTV 이름: [영동선] 동백교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/570/POc3OLs2YrNV9g5rxHusevdDIseiVr4sOtjAtUtFhT1or0LxMUZc6YIL5Jcpx86quE6N1NsM15nK3eZILp0+QnSWsbeCj7LFLJwpSSsTlio=
#
# CCTV 이름: [영동선] 마성
# 스트리밍 URL: http://cctvsec.ktict.co.kr/571/+i65/Ly1G2EMpHm5WStxcuIA9EEla1PMeO7faIpvaMbviMnhRRiUnlr+hI9Kk537gwrWPunUp5FZFareSTp2pFEipBwU6RIoIuyVPU1+kKw=
#
# CCTV 이름: [영동선] 마성터널(강릉)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/572/GUjmap7DN+YkQSYFGca0UY8Pe2mmLBWbG5FHQP7/WlJ6m8QLNX8Vklo1E5BffZr9g4YE8IRrH+6ZTuD+sMYBwodNkNENTQOz9hsGPEVsDjg=
#
# CCTV 이름: [영동선] 양지터널(인천)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/574/Gdi/QDZKfQXdLVET+tzNzG3HNgRt0EPe/f5yV3I7vK/Hf3qnVyb03G4ghr5Qh29ija6w93d6yMb1SCDmp4L2XL+G2Q9D85C/8KguGieaqHs=
#
# CCTV 이름: [영동선] 양지제일리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/575/l38n+mvY+Mz65gfO7w05bngLlS/6d65dANsR05P0cd5wAiubdQkU1yHLUMSWFVY/WSiLovHEon8mDxpoDUJRHtDMJS/lpoYobiKiMCzdBg8=
#
# CCTV 이름: [영동선] 추계육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/576/9kslxv4TnIRt376NNrd2cCG0xWIwkLfSV8gEAW7ObLR9wf+cAiC8pUdsBTAIHV9aXHnrIYG1As1HKS1RYsEcPvaXOmldlUxxinojpvbXVkM=
#
# CCTV 이름: [영동선] 덕평휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/577/XsmJ4msPTrLOFl3+xcu0A7f0JIAUWgW/tnuXPFujfpCapoukIHJA/fZRf4967UTVncNsZTbvEc2AG/LeLc3mLDdk+GDep4EfrYyhsr1Rges=
#
# CCTV 이름: [영동선] 고담교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/578/oLwKtAhEf64WAUvjNUFZRSxXMTRaYtJp8XF57ydlHda+lKS7d4W9AquQesGMCz2lVLYg+/4D1RRYhiKgED5UnD+l5czZWYJV3iBB3FSZ4zM=
#
# CCTV 이름: [영동선] 사동육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/579/HnTmMH+Hq8BeSLOiA4SuCceKUUhrqC4z0nZHzFbdhALJTwfb6YoBtTH8neIPxUjoVHeMRQpcSaboUuV/zFxRPEUOgK8TgrAH2YTZgfg8l7I=
#
# CCTV 이름: [영동선] 상활육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/580/0h/KhCYTfEfsRwyidEl1gnhHVD/9gLXpmB17uqwJFtehXGXT5QVjBaPdrNcDQP57ED4cUQnFp1Ej2Th3Onq9XrGcXRaNbnJg74PhJyqyV/I=
#
# CCTV 이름: [영동선] 여주휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/581/Op6jgQ83xq6nXbV5KA8oJqwk8KdU+wdlai2LtnAM/ijQk+4LKheS2Dsiv3aHRIUBewqZvQtl/dotALEiNeCSSGGog1jqz3WxyKXh2gW/NSg=
#
# CCTV 이름: [영동선] 여주분기점1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/582/5PQ/R4XBr/WJgtfQL3DTnl+DY2rwYb3Y0nJupDO3c3jOfK7hor922/RRvY7vlTTn5jvAaMs7VZ8UfDhV7HwtSRov5i3oBe3yK3KjvoaDec4=
#
# CCTV 이름: [중부내륙선] 청계
# 스트리밍 URL: http://cctvsec.ktict.co.kr/583/RySaTHh9HB+TrroBa9yV96XCbZltmRm2hdQEd+zwSc8os+FJSf527TKhrHIomp5ejm/ONC8Ylq9J7p47q8e4YfjPy/bwQHY0mfDINS21ra4=
#
# CCTV 이름: [영동선] 문막휴게소(인천)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/586/D9WNEfjI1jpStwrvdIj6PygUbPHKSf0Qs9MzaM0uMzLglm/HbD1t07FXNw0sBIg9/9/ofnmafvsCMKrEGDC/2Ii/MsxfAfu4K1WbzjjNqOE=
#
# CCTV 이름: [영동선] 노림리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/587/+xw4E4FGzRN1YVkE6AgK8oOmJ6dVIhyGdmCGFQgDt269eh/OVvXaFQZAO14fJqBL+jZfV4i0nb5730TejSrRqzGORDXCXOj82kUBwjbS514=
#
# CCTV 이름: [영동선] 가산육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/592/syX3DMxPzkg15ZNU5pHwyJ1/YuhRkjvBjec8StYpbFIzdIeQCJ8vyzdY9JPvouJQIze3TewJW1aFl8Pv/ztlldzmcfOlAiLOmeZDpsPpXHM=
#
# CCTV 이름: [영동선] 여주휴게소2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/593/6jivFcrh0QmsZoBU5ha8guWvJ+sLfnu7DIgSJ4n9V/bk5CNT0iBO9PNNZxUVYzv++KibSRk0cg6jlV5NNQ0NTf1Pe1dx308XleeaWllfu44=
#
# CCTV 이름: [제2중부선] 궁평1교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/599/e1W4jwpHnWS2DXAF0/dhU/X3ScAmO4xCuX5yPJPUCteGH1lOhyspT5a+aDOSy//p6VYM9brscQKs0wgI5UnW40Skk2m86cXfxZZzA2Zleks=
#
# CCTV 이름: [제2중부선] 천진암교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/600/WACP5t/MU5kbhrzWDRcqB3s7nKZtQ2gS3OrsTziG1HE9p80DJ2inR9ZmqbyajfJN1LKCDlyFa2qhmJuIonA7Uqh4EmIQzWcfNYc5VsHRYvk=
#
# CCTV 이름: [제2중부선] 마장휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/601/PfVsyBZrIae3EyEc26k7ozmdfqLkwJWhN3uR4FQO1smAmxAErg15hgvZovlN6DxDZeq0BwxQWJa4rlP1I5lo94IQhNPiCGWKRzREEzUPk14=
#
# CCTV 이름: [중부내륙선] 김천3터널(창원외부)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/602/rzAe+SR+xws2mVZE4AZUq82XnwDziJkiYTlmaRvOra12jRxu4AlxyHjr2zUbmjJABDw1wo4nm17ezgpM3oeMoeqPAzSXqvCbyKT/o7Ig1/4=
#
# CCTV 이름: [중부내륙선] 칠원분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/603/JMXiKDhEbh36hquzmXTj0+i2SMQLxWfPAORRyEVvqhC0ZmnDCBkk/BKbAhwCA+X0myalwukpr/vq6//+G0/H9PSUg/DorDERLwau6hUA8p4=
#
# CCTV 이름: [중부내륙지선] 성서
# 스트리밍 URL: http://cctvsec.ktict.co.kr/605/+NBSOxSt4tPJG4F0ZP9W0hPxKadiSum6cgnlw3qtomk3uSuE8PjvPBOTkFym5ogiw82qYA+NApr376+BdfBd5TO4cDjfTTdtDebuYQkEWik=
#
# CCTV 이름: [중부내륙지선] 화원
# 스트리밍 URL: http://cctvsec.ktict.co.kr/606/Qr8Kko0jW0Gc2D4y3Vx6bUaBJD/KsBk6WEGllTOfDhNPjGr4n543/jkprKqqKYs8gDzKElFqvWPx6cRhgRLFBaHJKQDf81iZLYvfdhcFAKw=
#
# CCTV 이름: [중부내륙지선] 서대구
# 스트리밍 URL: http://cctvsec.ktict.co.kr/608/pX9NAIZEVYQsrDfrMgoPuL4yfRofqya9CJetWthubl7Zb6yL+MllaEEf3ZvZ3DKj2dj3iQ33LWbU5t4vf/7309JLl0qVC+uUkaurt6TybgI=
#
# CCTV 이름: [중부선] 늑현육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/609/UgCMBkWHlGW4Qi+PO1/cDWb81Z7iH+pPnCkQvG3SMi0mJ20Zfn12zMDv1TuJ020CQhmdo4MjNDXV/dN81KQK6rnAjrRHFcwUYV+phTvJ0qA=
#
# CCTV 이름: [함양울산선] 밀양원톨링2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/610/M66g1TNE9sxtareAzw2ENu4/v+NXMq8gA+CC+Cfz6vGeUlKf9G25Ef/wZPkYg5vMvVE1fwXE6ekWD0vdaBsMLDnstyztchEp9SUr4ZU9CrM=
#
# CCTV 이름: [함양울산선] 밀양원톨링3(신대구부산선 합류부)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/611/Nsnwot+VWjb1I9C0nyvIWmZsYlmEvrwrjT1AozVvCB9NhXmjrUosujGox9KztW5ms0LaOWqrMU8bnchvVvcc/xEtuiiY42ym8Qquvdm5Zck=
#
# CCTV 이름: [함양울산선] 밀양원톨링1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/612/4aQ1uR4WqrYEey694tHJZb3XgJPjQAus0Vtyga+bQ34ltlr06sIQ/Tid3SqBEa+haUar3pEAlh+oKr/J1PFgwtWqeJVvwnS3WUnpsRTkcQo=
#
# CCTV 이름: [함양울산선] 밀양JCT
# 스트리밍 URL: http://cctvsec.ktict.co.kr/613/e6Yo0BJHCm8yvLd9AM5bnJaz/idP9RkaQ08bzGHM1aY4gZPF2f8Te1GBvQ+LdpOEHFd0uJQKfCLXwoRvzmdIzrWL0cP8T40ct0wftjUsJj0=
#
# CCTV 이름: [함양울산선] [울산]산외3터널(울산 4/8)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/614/UiJPj3TtOrlYJcHlaCgMPcIAW/r45NFo6aDSHsnUfeaSoDl9jiUsZUYlNsPOeXxl/znktKwm7u6Tm1+cuN6Tz3oxxahB1KkvVNInNtA4uxs=
#
# CCTV 이름: [함양울산선] [함양]산외3터널(함양 6/8)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/615/EBR7tNom2+t4u7Ai8Ays3sObuGHpEoNp6C2t56X5Bjn9QFvtCQ3tEO5+90QK+28miEZFuxkX3EYE2UIQXwxS4gmXF0wk9ACuYiVAnZ1pTuc=
#
# CCTV 이름: [함양울산선] [울산]산외3터널(울산 8/8)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/616/n/z7Vip4rqLeU2xUQUHdV+/TyQgvBfGix5KF3H/h0rXhEersASoA5KALyCuM4ZYAWgN/3SR8bOSccHpeMU+OInujfT4NTNrXPZQuGrsaBPk=
#
# CCTV 이름: [함양울산선] [함양]산외3터널(함양 2/8)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/617/BPKm/P9O6qMl6kFNQY1sr/bgqbGQcDZmTkP4FIHh8nwx5xdvv8BL4fVqZMo5DItFiDeABrp/8AhhyNPOfDAoLcACfi7pyoJOl4mXAeiuHWI=
#
# CCTV 이름: [함양울산선] [울산]단장1터널(울산 3/6)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/618/h6VW9UFx+dUfRNI8aVDqlsGdHJHdQlytoYavoQmi6R5swiFz20wICDiPmrdzzoQwALJi3lSI+JTm1lm2ZPLwbtm4jfQU+P56Ns6e2qNfrm0=
#
# CCTV 이름: [함양울산선] [함양]단장1터널(함양 5/6)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/619/v1DGXf59kGwz+I12JujEv1e4Giv2GQAnyfSBoHvNxCjREVyWTQL7azL7UiOtGtWXN35xiVoC1KlTo2oGif3hU7rrz9u6NASBYduMJRqPeXc=
#
# CCTV 이름: [함양울산선] [울산]단장2터널(울산 1/12)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/621/KBKw+uwmQM5wDEJu/41oXUFhm2OMkl8CUA2Miw2a8vpIguavIX9O5ndBoMVuFVV4q0z/AT6vCxVVFn2aVFoNS5rEnHNHmzbb80N6Wup44dU=
#
# CCTV 이름: [함양울산선] [울산]단장2터널(울산 7/12)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/622/kTVKt6uS5N5NUic9BzLR+OgBGbTZfqZLpjn7dPKB21LaU2nuRjmmVBbv0cikC8rSYi0Rfi/+f4RxtfReI+9Z0Sxa/i/8S+ap4JWzpIIecMI=
#
# CCTV 이름: [함양울산선] [함양]단장2터널(함양 7/12)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/623/MjOH/w14u5O76y0oXKMZ1Xj8mbSM854NyIzRSJvKdIyu2GESs2Zkuj+JdlREKoeTGGjmpZjXJR5y3E3ylWf/5F0NKKG6bCY2VpoY8PfNlgA=
#
# CCTV 이름: [함양울산선] [울산]단장2터널(울산 12/12)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/624/4On9D/we1PIE1S/ymw9Mlyh3ptBkOSIEtj+XsBIHrKAms//eQBfC82mJC8GVQ/XgcJFgDcLTV7gNhElQjiJoheRQLyTjsQND6m80ix8znDg=
#
# CCTV 이름: [함양울산선] [함양]단장2터널(함양 2/12)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/625/+bbglZXTT4iCq3gNAgBnsBj/lnII9CFxn2P+9/V1wFlToepuIyjfIb4bMI8Uv8KWiWRnzD7mqWfLD/SHCOH2/JtJyjmn5vOM3BeDci1B7wU=
#
# CCTV 이름: [중부내륙선] 탐하
# 스트리밍 URL: http://cctvsec.ktict.co.kr/693/LfTgtiKHVztm5F1Iugx1ouAxFbV/OcQcabN8OhPiVX7oloSPgjrxJPTJGVAgba0V8Z7SWT5avwOnjyE/rPNl+vRXo3+1nhezvz9zIJG0tlU=
#
# CCTV 이름: [중부내륙선] 효정
# 스트리밍 URL: http://cctvsec.ktict.co.kr/694/xjNRg+8LAFtcovK5vBxY1GrJQSvkTZFYCtpZHCHF76DPvbjjU54a1ZmHCd0krjXlINvBNaz0vt9XYm0rBCCOtEz5473YjWmU1zXv3AiZkAk=
#
# CCTV 이름: [중부내륙선] 모전
# 스트리밍 URL: http://cctvsec.ktict.co.kr/695/VKjuy7/VdKTsKwilRt8d/aoU3GcXWM5YMmtvuY12KC53KqSx8CQkml03kaYPXuebB4QAYSnXz98c+g6tz1pWJ95atIx21LEpz1flRaiQa+U=
#
# CCTV 이름: [중부내륙선] 평지
# 스트리밍 URL: http://cctvsec.ktict.co.kr/696/XMEoaP5+rs5z5ldjnRkJlQ10NuOWxVExzNNbd59aalqndiyBk+Wx+SRlfTOaqMzAHiTyjvjXj8jGhuUZNlPtfYTJtOKkE1hsGPsXPEmfTZs=
#
# CCTV 이름: [중부내륙선] 낙동터널
# 스트리밍 URL: http://cctvsec.ktict.co.kr/697/+aVu6Zvp5PwHKMQL2wCqOc40eF5VpPVHW6hVRtnusFZX45KvYmhE/klCaCnygkcYCQqFr7VvwpwWUDG742y5c/RtiMYRzJ3Ivm/hBOHsFg0=
#
# CCTV 이름: [중부내륙선] 추점리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/698/Z3ZgVI3v84Wq+XCxIbumSyQ5pCx+Ukq6fNPqcd3TXugoE7sxaJLIezXIOfKw4GQE7uxdQElayOJ6W29XfFaW6gGW23AFSZdzFTJA2bXPRWE=
#
# CCTV 이름: [중부내륙선] 단평리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/732/JeocnrgOlz6pr4/vIJZU2DpZO7hDcxvdbH7k05tz4vYIZNMlDqvrfr1gw39sSEvQdKH0qPd1mYG2iwgJp/fNCS3+kIm7QO1/NbGN+ZVQIcg=
#
# CCTV 이름: [중부내륙선] 원부리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/733/jE43UlkiHvBWLfPGQL5j9iayfcZsZQtfmsIxgBnVtVWbVsm7byd8DHu5mKToxT8pEnK14SHIwkREzjBCi2z0W90a+iL2ej9adQxW/yDyJVo=
#
# CCTV 이름: [중부내륙선] 안금리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/734/58Qqa3GGYnf1mcG7irnZ9+Wv12f0sa4RtDGRRrF0G/+xkxj/TEmIq+M8dsijlBrqSbxLylPXQN9yb5WMti+QgAyecUicWMqDmIntV2ya7sw=
#
# CCTV 이름: [중부내륙지선] 유천 하이패스IC
# 스트리밍 URL: http://cctvsec.ktict.co.kr/735/T7kMlJC3RhIxq9UZTNnsookIZCq+GrMYO1NWmqioXfbMKXhsVtvjnw7I8KNtQOLIb84d/dy4R786eeckT8+z4890WpAPLn8EH3QCDc3ZO3M=
#
# CCTV 이름: [통영대전선] 대별3교(고정)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/736/HnTygwGzJr3fSfmk01GPWE3v/DOEyBhseRV6sQOkOzVP6caI9X/8qd+LTG8aSvGwt4/aF8S4SwvmRIuNpWw31oUN3p89N9r68ZMWnv4Ig0o=
#
# CCTV 이름: [통영대전선] 은어송
# 스트리밍 URL: http://cctvsec.ktict.co.kr/737/m6olbx60gt4yMO7RlB70HPRpSFMgorOb7FPeP2HuBPTzjaBOUth0N1/jCJj9PtxDfiPN1XRZDth+oJPgyhj02Iz1nmot2AeZoW5Tc6YdF28=
#
# CCTV 이름: [중부선] 진천터널2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/738/wF2qv62aeMxs3cxkcwcnpHXDRhhw2kATmbH6oloJgzz49Lex46omD99rdhc3JLc464bdUMfklWdg4Oj/GXvYk2yKUSQHB0viDuBwoIITR1E=
#
# CCTV 이름: [중부선] 화봉육교1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/739/uKb3Wn4oj70dDQXF1g+3r5tK0aX9rP5l0DYhSW03dKNhDFity9NDJD5uGlX7WcZrqnlcIb9N2ei+rcNZ88s5oEyTn9R1Uz2WKVoyzEwv3lk=
#
# CCTV 이름: [중부선] 장암1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/740/ccuLY+4OP1THlDxsvPPTYj7Pesx77bJQP3zAKF891oNBmAMgiP1+mKUm+G67JnY7UuDdD7LGY78dkpmRAdsytJKfjse/uhAdAH09C/taah4=
#
# CCTV 이름: [중부선] 진천2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/741/tlgUouMM5EOUhcDjq0VeqJDLfxhxLDNB2NprZ5zFLGlj+9VP/tz12AeR/4PckID3ezsgjUgaPqAbK/t3V9OZSq6RabDVITx5CqptlPH500w=
#
# CCTV 이름: [중앙선] 죽령터널 졸음쉼터(부산)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/743/05dZINdvT7LgbgqC8nB0JVT/A7KcTDyvOwWJIMPKAqiHDPolAg5jwP3wKc1PzBM/3jvj3KH5OBTn3m6he2mVeWiIRoxpMEpriv8n7BNoLjU=
#
# CCTV 이름: [중앙선] 죽령터널 졸음쉼터(춘천)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/744/F2rsrwWSnI/lGGLGpLrhNeYHnGv6lrv0gqTNcCThfORcxXu+5vabgbuzoe/yu+ymwbn5caHYInutinM9Q4qp7KTCCNZc0vi/8/Teymk96HM=
#
# CCTV 이름: [중앙선] 월림4교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/745/vdN3QXlwnKxKYKURSEXjMWaDIBwV8eMpO2bXV3a3a+Sh6tjHDEf9FGc3xLTxUjYZT9KS2IXdEup9Jp40aTKeB1zLbFHEORseQIeURoHWg9w=
#
# CCTV 이름: [중앙선] 장평리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/746/zQgtXf8mIvfn9N/2ZV9Ico/skMfB/kA9yCRfJKsqM8CyFTiAEeRjmFXYJ9UHixNw0sppmGe0kL0Dggj57cmFpZVeY5klfDmKCu+OMqOOnaw=
#
# CCTV 이름: [중앙선] 학산리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/748/ziO1ebOkQg67kbzthJH4OYcMQLvcgsLem+Dbyr4JnewWiFu327LiMwui4ovuuds8EVlmBnzs8FmBAaWh1DGzfaW4LCBPGYsV1sS5t1foXIM=
#
# CCTV 이름: [중앙선] 신림리
# 스트리밍 URL: http://cctvsec.ktict.co.kr/749/xn9uCysJ4S7OSX9ozYc16fWO5hzHQ0kSnOQrKL85OcktOD2CrE44iprH6t86mK+YCVEC4qs8Dfg/nm870d8raaKTE47vPYYxIyNOUOMFJSk=
#
# CCTV 이름: [청주영덕선] 금굴교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/752/fYei4N6Bj77thQOX/uZ6sDcU91XunXWiF1UOro3goOgV9BWj2wn94WORWeJxpMxtzOLYKnGmRxGtrKohNgFaoJa4B0cFs9pho2x3LkWLDPA=
#
# CCTV 이름: [청주영덕선] 평각3교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/753/iU5aDLswE4SoPoNex3lSb7jOt0lBGPWruFqr1X4KjeL1tNKhzaVAIwBVoj+wBeMOFdZWkb7f+hBIAuVXKxFSCRnurDbE+dJvVcqzqNAV6MY=
#
# CCTV 이름: [청주영덕선] 갈평육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/754/jRnSdbOeNN9IdmAlak99WntNhcvM3IxPWweecBBsdirgvmRYGgM7G744d9oXssEZY5LWjDCriMYLhAMuDkUwE5F6PpyI2Ago0H5SKxhbtP8=
#
# CCTV 이름: [청주영덕선] 지사교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/755/ciT+kML3KG6H7S+7ymmGfPOeyhKnnEhWwdL1GJnF14GirHrhMOlQ/j9lvLIlWraaxXsbDRrCPY2WMmoDL81bzAF65PDJ7WlZLnKHI/tT90I=
#
# CCTV 이름: [청주영덕선] 안평2터널(청주외부)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/756/HOyMDQwL5kJrylW7csi1WYXqRGbfWJKOKv27181ILriM5PAu08JWpXempO2kI0zWuvCrHzklNTlDFhat8bdvIuooqSKT/IJqgI72n1m2i3Q=
#
# CCTV 이름: [청주영덕선] 단촌3터널(영덕외부)
# 스트리밍 URL: http://cctvsec.ktict.co.kr/757/kkAFJICl/G05H7xXCVyvCiErmz2p4eCwiipewDYgYOawT1k82qpG/RAUv4dFmo2kL78ZZBx8epZnlXkIN4ueuDAw4MWFUqvOzvXapBLQ57o=
#
# CCTV 이름: [호남지선] 고내육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/766/MGJVZSZcpz9tmATxfTc+8+4Jdv6R93dAwEeKLyeb00ByLTICu4WDnLPOfsGh6cb6AOwUTxASXrY/lae6TqyYJ82QrDJqzuryO+yXTmvCOEM=
#
# CCTV 이름: [호남지선] 소룡
# 스트리밍 URL: http://cctvsec.ktict.co.kr/767/TlKYQf3XSa7I/S97ml8T83gP5+jqOkj/zpJ3Q7x/wGzu8Sc48KyT29x0AEWLqEBAYXTBnoG7rl79Wo/EVqDk0/T0e/E08IhpyEECdn3XLK8=
#
# CCTV 이름: [호남지선] 조령
# 스트리밍 URL: http://cctvsec.ktict.co.kr/769/hkyVzybIDc756PMpvtekw1Xq9S7rcp9hevR4tqMLMnLXb+gkxGrD7obI+RfgzuwPkUe2iJR9srONRuPqVY/wFQfmIiGZEfT7U/Fc2u7eWQc=
#
# CCTV 이름: [호남지선] 금곡천교1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/770/YytAOvhrGE9cXsDFwKAunzNDNFyQGJepFUSDej1fta4S2X1eQmKRYOwCBYnMkvNAcpdAiPQBOQbgb11bGtva6x/9mdC5TDH9LtKMdWYGe28=
#
# CCTV 이름: [호남지선] 설목육교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/771/PSesDl0Ups6TiMw07xiARDXVyTJNotxa7e67VW47buyYipN+Na4ul3J+OPfXPNDe2CP3pIoonXmx5MppLD9PYAbS9GyM0s/RynK+9sfbvdw=
#
# CCTV 이름: [영동선] 이목정
# 스트리밍 URL: http://cctvsec.ktict.co.kr/772/CMAfaKQgpU8ifEqPFp4k/coVKgksumPOm6A+uQsArjDjiLJVekFU7V0dp15wLx9NbCCSje68OyWyE9e3FEQC/bRc6V9tWiohDcPmkRViQTU=
#
# CCTV 이름: [경부선] 안성천교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/904/JbCJnb84H5jazEGps9A8QqQ1WMIwXfy2k/u9J3Gpv5lfMiqxZHAdaYFEJiAyZS2NCr+DBl5HfdKS5YKd9iVGM/EVqQZbDIFc3wE6Jh3ojsw=
#
# CCTV 이름: [영동선] 호법분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/907/JAJuTgCNT3iMBhWhKqENw52eA1mijO5i5V/ggrjs2KSbevgMjn5XY5u10miLVNZGeLrPx+jaQ3uQ8fwv2ilX+8u4WiQZQayiRkr1ElRfEq0=
#
# CCTV 이름: [중부선] 마장분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/908/dMr76VWKDMBMzUri8W2CISsxIVTvlujOKLESjI0eSXYgFhltT2A8S7TYbdMAQEFFKx/X30G/EoUFClzI5Et8niVAdH3NIpe4vakrsYJ8Jes=
#
# CCTV 이름: [광주대구선] 지리산
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2001/MF49jxiZs9WqGyO/hpjmfgrvfVRg/ZmyNNZ7TYSBPgfFv0ygz6bzMf5Ocgbdc72UsNq5GYlOtZCljZ3BgreEryOeUZdpK/46oxqwESCR53E=
#
# CCTV 이름: [광주대구선] 남원
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2002/1+j1sbC2TWPcTX+kKp7uWEhAyk899p2ufLKr/yVuRwBeVeWwKeJuU2ug0P/Bry+zj1VwfiX1WDmBhwMrCTOtPOo+wg98VzO6nlbNkVD/99c=
#
# CCTV 이름: [광주대구선] 순창
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2003/W8tgDtNNjgyQ+s5xNDjcvWjy6nKhPYz5WYNhiI48E1mQEpaC1IjYE8fb0T2gU5+jn/pmXGtxeN8K3AcIQpXQsbHWGjJD4zXUHQEMIXwa6h4=
#
# CCTV 이름: [광주대구선] 옥포분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2004/aE14OFf1SWgxMYFxlwAaphAHnUy1oUXSV8gvKe8rJdZWiGJcsB02GD20bd9tLQVNlvItv3EbsGMXn/N21CCVDRF+o1xh5lZaomZFPY4k188=
#
# CCTV 이름: [광주대구선] 고령분기점
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2006/DmoAZkKUq1gdELdhgcAolFteDRK6M9uJPAJ5DZNTA+opuQ9IrIGy2lKPcEn2+mV2pLr4RaKbh7dbo2RDTcVQ36EA4I0KnGKuOhYwOrpV5TQ=
#
# CCTV 이름: [광주대구선] 고령
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2007/Po9RkfY/GVQ1WCjS2n/FKQWfMzEH4XulvSyX3OymvjISWLWDq4eYT2dfkYi7d/8sB74xZtoS8bPs5VrX6qeVxCPo6tdFg6ZY5HHYaWIgHVU=
#
# CCTV 이름: [광주대구선] 해인사
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2008/1QTumbPURO5Y+cJCN9de5CQ7tTPhaDdkTXVqG52AeCiqmsKU8t5/EL2GaMNmG+WiVuUygW0ciEUfd5NYwDlZsxXRzwXFveWj/UdPjGVko5U=
#
# CCTV 이름: [광주대구선] 거창휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2009/c8cFYsNPUoPoDo+1PQdTuvl8HcJtM5GuIBAeZZM1sH+GZp9qlfw7Ut7102zzX7iq48QlT7lFhvPMNebSFlmTLeOtDB4rhuqA4jHvHIOU5bc=
#
# CCTV 이름: [광주대구선] 거창
# 스트리밍 URL: http://cctvsec.ktict.co.kr/2010/fIJ9ihVFuBsZHrNBPKY1MkFA0qpk5sh0bs+Khr9WWcO11nEFAaOJMiOGVM4g2vaIxPK29GAWM2G8qdpHxMGCz5uXl9WYGePPleJ/8NrWVYE=
#
# CCTV 이름: [광주대구선] 함양분기점
# ...
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95708/h2bc3wu1O95w26soyjsXsNzKkF1Hjg5/CmyDlrWdQZmKb5CmXXKvMmP9GufJp0RhA6pKjm9Xbiqo/ROQSjUW98lXp5ROc836O3KqKa18MCA=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(함양)-13/22
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95710/DOnYK6NHvI44XehO0xCbPdwjrX6wlfpBkYP91mlhb7qe6iCPgQhVIOefet8+NtneU7G+eOZwOIxNYF8uvoJuD+KAvmcuai6sa1ryu+0EP7U=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(함양)-15/11
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95712/NXAApXPt5FgCuO1/DD/P7pEKrTvN7AjMbEv2VvxNZ647RQ8jZR6oDxuIu3e4c5m6lb3ud6Om7W0uqK8lB8NJXpk1q3HTSzhVKx1iyq12sG8=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(함양)-17/22
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95714/IAFHkFkCW6oyBWHkMQGaF5+HaYmA60d2A97Ldzqvy5NDaKYlkHz/94pYGMyzl4jRsTSgqQ9ZaZzGuzeWynul5QBrQvL6i0vXCab8ANX9YE8=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(함양)-19/22
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95716/LUUQ8is5aDgOmwGbWK/ohj85kjJQAvKtZ7cG0A9f92SAp3bQORBBbKpeJ5X3gvzJViDe1rYu5XSLaUxsg/HOemKJuEnunvM0e946FrW2+DA=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(함양)-21/22
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95718/D67WLxEIS45fWnZ6hIhGYRQvhlatLTl75KS/cwozzma07BO928Vr72hUWBV/TvyIreQrQu5pQfsw+G83S81cB88tHQMjNns8SJgXWVHIywU=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(함양)외부-2/2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95720/qP/apQ7HkCAU57pXmQwKZZ7AXeFStJysnHFGbfRv5CYKJGQl+FMMOWzWUyf2QVfSW20B3QXm6rtIBKHBiz/GtpsVBjJdun1sOwcAFZVFjsc=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)외부-1/1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95721/rW0qZBM/y+Cz6a0xcId21+Iog66ZmP+F+ZFV4d+BGh+g6uXL1760xLcCxMNit2xE1ZuDxLJzt9dY77rq4Vy7JmMZeMPeX/wNtSV+z7mTVFs=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-2/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95723/jCsLPP1zgsHM54EtETdmnwTsuWNG7sQmcPL/m3eNLonnTlF5YA8vyUv/ZwKsUgej/W46DFGJwFHMglsFL0uVvNpSI63VkGHlFk2Qa2ugHj0=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-4/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95725/JUvFNufETCB0i/BwvJw5F4vVH30XWXtFT1L0BKr9vem89fxOu25k8VFeUYNTT6yYu8K84u1u7f9SBbI1eiKfXqlIxSu7kT+EzFu/ohvAZ9Y=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-6/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95727/JMgMoyxqwErz5Q308zQXE5UV9yTr2A2h8KK+Y2jb9T00w6hg9524TZB9sDDjjEdQauHf4xE8nAogdKlsbqzomxWo5FkEJ2tJ16h71rscC38=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-8/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95729/d0xVIRLi8exIN8dX8M5Njs6mYEm7KZQ1AgrO+ZTR6KfEQMyUCStOhRy1SJmKxd3JfcG7Zq1xhY9yNKwetj0xzWT2m1XBlDbh352WADIYO18=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-10/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95731/OrN+wfYus4ZhRYfT8WnjbXbcfGZ+Hc/otJlxlewYPcuULr7+IFq8V2opr8JYQs884bPF4hf7lKto2e2G07JMnsV5/xbLu12w0Z0C2iyOGxQ=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-12/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95733/lwYiImYQlLfikyfA4zBBAOVE5yj8ZxKzDN7F1T3J+4r5r+JQrRx6xKPKD9geo/rp0kRDHBuCaGm7m733tK0BOyx3IXNDP+gi4bRVfEEzIwA=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-14/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95735/OnOQZ/Z2LJkTCVreyxi4W1zPdxWiPTxJIWe6Le++Yt9Ju4JNg6GTcFx71SV4OybRWQYPJaljj+8k/B/gx2Y/MmCJSWhiurrB2TrnJrlbmxA=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-16/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95737/Pnc1e4h9+hbP+Wtn/HT/ZZ3L4UMXASPKjgMiCpE+tt1+3pLWPM/qwn159iG49/iGQIMA/syxrDK7w4FHjN89uW3WxXpCnYIlKgBucx2zOCc=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-18/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95739/DwWakSPOhq2ODxttEGWjtJPa61gYgeSv+UxHG39RkZdBvcPyoeI06AcyJYGHAfCMqh0BCVCmwPD6LTGDHpVTjFTZ3Ltldy+eoME99Q6Rs6o=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-20/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95741/UWh/XvkKMDYiK30R7axM8zHgSWMDorvpkAdb+c/7a4+N91k2p2ydYOVclsVmp3qInedk8OStza6ciU0iTY9IhFfNoyttBTCgXxT/xaYBXX4=
#
# CCTV 이름: [함양울산선(창녕밀양)] 영산터널(울산)-22/23
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95743/wV2J4jgOqNbjkrbW6dN47qaBF48yWSLQ1QrdJBKbmg/dkkGIz3WLWK3XEnZ3JUDV2ToJvM9aSPxhF0juxzTXNYbjVo41C6FaC9YSFD3UVTo=
#
# CCTV 이름: [함양울산선(창녕밀양)] 밀양휴게소
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95745/NUegBsvImFUORfrSTs8lStMwiEgvxQWcBfhLIlpILn84EI0KjiO1mYgYh4nlo9TJTE5Cv230ITiZG0LJeMYTskGrl19UCAZGPJ1TwmkwXoA=
#
# CCTV 이름: [함양울산선(창녕밀양)] 운정천1교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95746/Av/Rz9wcjD6Tc0TAbHxqjLIrPZFxouOhzyjRTleewVoodhmic8m/BAOxo1taykbgD/6o0RotgSHC1SFFkpNN6xz/Y4o2d65lbiJbA0EW6Ik=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북교
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95747/+y+vl3q0pDfFc0er8WzbFWNU1ERlOqQUDYGMjMKv/2sKbWkBtBhrc5NZ55NaXy3OwJ5kWpG+irOpRih2zDV8zyM1glKagIx8svs3CoFgcoU=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(함양)외부-1/1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95748/8bJSbYwAsJpAJl66lGE6SYI5Ms4pvYjI1jwdpYlZqUepRNaWwtd0LiDJTVeLNVamcTGtV4iLqusMFDuxUn8ha8WKPgpweLBaJFaS4ucZmGw=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(함양)-2/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95750/jBDOIEOphYRKosMDA8e/yPkGMrdeLyAVAAAb+/99+6Ajfru1Wk844+YAYHO5bOXtekhVWDHUJw1oUjf3X46J729+pBeNMN0RkBk4EnDndgw=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(함양)-4/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95752/WXJ7fOpviZAbfrdvHwReMO3DEEKFT5bGvUbrInRozCwp3uAPS+94aqB5EdBo8immDkH6Sl+D26Jl6Ajaxe0x4j8roAuCM8d1+4Ub/mJ1rDo=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(함양)-8/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95756/HXEUdFG5G+HXmiuFylzCmthqJ6Eag3B85W3mxF8WNvKT8GfAA+SsHxWifL+rkKzVvz425nGJtyWL+qG1hIgvkosRq+QA/6sMoAFFE0AbUM8=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(함양)-9/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95757/2hgSpLxEdzIDmaq0EUtVskGyd9mXdR5LgTMnzgGCLsgGnL6cJWrDqeHBs3iDpKTK8h8fTaNKoZwg2eH54L6HeTKYNGApDyG5PB2UN6HWJGI=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(울산)외부-1/1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95758/YOm6KQZ5vRG9Lz/SwgPV/m6urZWSaX8dEjis3/uXWWvdBdLKEhWBzbmhukQlnBOiAWXvq/q2K2zsB1Rn+QO27bEFHiVIy2Q+WBSfozAYSmg=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(울산)-4/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95762/VH+Hzh5o3hoWtsaHro55y/Jc0tM8EpDz78D6fdI9uBTaLRXfiDqo9RM9dZWaOW7yw7rNelqflRQp8fbzDgf9aBrJSsQbUs3tNvyLao3CWnY=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(울산)-5/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95763/N0PnWR7aXcYls3yIiOkigoMrZHiZLWOC+dzv/H0Z6Gz0zLkwdmhCcDoAsY3iSXgQ1qwJpDsRVlgj/XeIlQLw6P0sa5Ef0k037rv9dZCQAQQ=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(울산)-6/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95764//5CKW7LfJv30xxzZ3+YAbncfCJjW9qmu9VHM539sgVLPYV5CcadxZX8nW07NHg5OszQasB+/uRYkDk/QmADgcOvNrAB2QRqdnUa5TMYM2W4=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안1터널(울산)-8/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95766/7kd9iOS0up81opdXkhxPAHrCRg/j/xJOe3ViMHvnuRGeuKsCkfB2rWjaqGQJjiFr/kq5IDVPp/MTsZ5Lkg6NSfFZFoRYLB3BUvQL6jlHhaI=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(함양)외부-1/1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95768/AK7EzjH6YSKfdBhJPrqYgH2I8YqmPYe4W1ybt0dMKNNP/n6XNiFekLfeXLjyiUVwoTzsvVBBSwumhoIx7/GRAzrWuYIhRp6MllSrAL9aSQU=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(함양)-2/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95770/qfV/8qPsQ+MhjQAt6C0dQJHXYfGJD53uTc4kFc8TlnYpPKGOH+akT0IlmfRFSWY0f+wnv5gclMmkijgg8khsmo1quxyTeWiKc11A/mm4Sls=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(함양)-6/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95774/zzc2bdzZQTLdVFJVUXOjpxDoLFgi/879eiIfGnDCYcHKL5CFonZR3HjB1qb3sWlRqWxZTumSgKzkIztEiI2/jlGCvLSayvoQTsXX1d0MXSg=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(함양)-8/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95776/EUOicjVMf7dlueORGqSR+gPH+sgvth8LhGzqutHooMe3SgA9FtJWtr2ESJ/l7p36CLQltMjAg4hX0f9dduERbTVYPzSL4Xss65AzCXXV23g=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(함양)-10/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95778/xDtGtAr64uJPLKC1jD8wIi4b3ZeQdB1i1ysmvEwv3cTrzE6Qjz+IQY9C2lxvy8tn45nSJLe/IJC0UOSGWRIcxUVsGJ4RkuW1ns0oNXDJA6I=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(함양)-12/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95780/2mmueJSk0n3C2FcOFKCgSiFBxl5trUf1MPWK0CmyC7/X06M+JDi/I0VswFpPk4Y+MF9OMMUAGRD5KuFVmPMUmZTd6+PUjMarVDguW7TSt78=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(울산)외부-1/1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95782/4jEL5wHfxDFO127nuMAuatNnJtQSGnE8xwQHBhZAyO5UIJyDdRAkJ40GeDvKb6d9D/PGrBulFnqolwgr7NDM6UJsFHxttr15lABfztDBM14=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(울산)-4/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95786/PUNcx1V2YaPuKnBXrZk/2Cjkl6PWTpKWlK/Gn09VsJV2r8V+lihBhRG572dt8jIQ4EsUGJgq7FOaqWddgd7OaNHteA5s21Kz9o5iQtdUfdE=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(울산)-6/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95788/DhZgSDEIaZ3oB9BZ2FANNcmI97Pw6Hslhag2QMFzolYqevbYQAWwqT7+JvHUp8lh/i3RsNaUXrXlD+OgBprX5USQdbEedONkf5A1k9Gs3ZE=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(울산)-10/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95792/rmCR2mTpkd0icnwBG29csP17zuv4zaZ008vTjHFNgIGy2EmkDGp99yilmQwAE6HWTk5URgbhiCnUBI7Q+YIzMwfOYQ84wZ8ovO6hBvIdfG0=
#
# CCTV 이름: [함양울산선(창녕밀양)] 무안2터널(울산)-12/13
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95794//fHDH9PFH9Bj4IkMaAmMqby0RguFOb9DOpQyOcaeAUyiCX5on2W7vp8XqPzGU3jrQPnFSyXEsbltGhrJuHPjy7TSE3tBtqMRB3/x8uOxA1o=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(함양)외부-1/2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95796/+it8Y6n7Vk9h/kVkuviqQ8GNerdVFPcKPjVXX+QWh3pixm/e9RABrNxP0Vol2Dv/UZ/1vnWrbsilGcje8g9YCdWyjBLtkb2GDhQkzbHyjrM=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(함양)-3/10
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95799/PO1KLk52Ln7GqCYjLk+aDmyFruFegLPUmWgIz5JKdjgF6YdJYEinh6enajij8+fjmBpZzq2GmJyGBYNQtMYALY/UdN3waiqU9F9qyA+/0Rc=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(함양)-5/10
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95801/leef9gnh9F/TeiXSSdy9BvKSweho1QF/V8vm3o1nspL0H+hhjkbMOj8tMCgSyd63RqFsTGQ8y4OJ5QxUiO3SbjArhkEiuU6/q0arHNg5US0=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(함양)-7/10
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95803/yc2tnmaGefRWKruoHOQpZ0RWa/KQGloxPu5nF8Wzfp+bEoq0hRKtI4d66425AzIuB3DM1Weit5M6ikkutIootChquRoy8fG8RVNshNoiPQk=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(함양)-9/10
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95805/Bgtc8u+02b9XVQMsmwSBMy+aciroXQCEm37Ec6PwvUN8fCV8D8wBElipHTICFhMmq1QhgpRzuDWmN0g1DOLJerlCgYc2hjZQbJx9GPgLHYU=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(함양)외부-2/2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95807/QnzRm1N7PNvjZwEDg28LXpl6wb5liTVXDhS+ct2HsxKPvM/7Lntbs0UMNtsrWspkHf3YsUOTy04rdFLC62EvHG6VsTLNn1iov3Z3pBAg5B4=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(울산)외부-1/2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95808/DD6MqilbLNJFDO8Yzro6i5OZ2KYT0p663yeAwWIOa7j3YvaAo0HD0SHCIOveLWX5az4OUsRUcbZJvRcxW/5V2xrDNEWI+U6ofLiMF6Yctr4=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(울산)-2/10
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95810//r4wC4EpXQtvvQ1aDVFVao5ny4DVhxFNcE17Z/YyliS+2rtOuEzG61pB8xCjtIMPpzVw6Q8Hc9KxLLeJbLz9HpfbCCRoSbiNr+u70b82tLU=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(울산)-4/10
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95812/e7zwrXXE/Cdfkd2oKnUSehqAgQvdBTct44dYYsBzmIda5npFFAlxtngfUMyh6ikWBBwl4mljVq1PovIolHbpiPmhXORQECkHi81AC6v9NaU=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(울산)-6/10
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95814/rcWJPAUOnc9o2T4HnL/AENzUsBnh9AAvngXStociYJLXA2H9XTEAisfpSTFiNdBvMetFhF6K8XzN0fE7XfiX0IKobXW2nBAM0QDXbpDh/SY=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(울산)-8/10
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95816/uAaxDiJ5y0UISIpwSF7M5smoglHGmefhF2Nrv8eH8+1Z5kVtA/jGCgPXE0ylHo8JOAEBDF8RFW9CuSO/aYjdS6iSjhqowiqUQlYUF5XlqM8=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북1터널(울산)외부-2/2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95819/ikY5yDCBDTkCOsf2Fy8yGR1/FzxmtGm6hZjxMTWxA9Y2C1ev2T8sc1btuBVRRDQj0IZOm+FkOEy6/6eGPRCA4QsipT4LNwIWULlBxalLrnU=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)외부-1/2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95820/LmIWEKLXADZOF7f8qZQAwIY9oCaUcgvcxTmVjnJB4ruphlJL2sgPjZhWubxgjBeO5OXPMoxOxQtQ5xoo/o8qb0qIYv6Y9JY22OzLuIGD3iE=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)-2/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95822/WzJPAqZbgz41HYRXZMrAe3DearEhXCoExruqhpSUVROmB6X+1HhUV6w3+gYWiuXa940EkYqajyuU44DZ7hgegq1YGd++e+9oM0HeKxrcyXQ=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)-4/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95824/b1mZq2G87SIvoMaBtNxpfmAGioQJinz20TA5ij12KEiwWbzSJ5Gjo/3UJVA6Z+KwzEzpti3YNJzen5Gh59MeUFD6+8cIMtoyZimX+zKc8cc=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)-6/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95826/jfgOJX4pYoNHH2lweIWNPqcbPCGU5ZCU3b56rUE2yJWe6ic8iWHqW45klEiNB0p53BDfYTJgpQcXrMcW8Fr34LEyEYvo5XX4vbF7iS8rcU0=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)-8/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95828/Vx3je3Ch0L0LF/o77nZEpvWL7tPjv3JTM/Jq3NK/hWHnh5Yjei49p1OAdkjvNBBUv0gVG0kPyrCXgn+O1x1kJ8NWF7KQ1wAS2o4dqIAc3g4=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)-10/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95830/6dcks3SswXIfNTDekiTlBCqu4faET4z0VDE6vnQh/C4lO30GF2VxaRsM1BKHDxDyuE9d1oI9kqe5cj8oBbWQvS6IcXb0i0DHlLPES7hG84U=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)-12/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95832/bQ5CzByqYD0udOMOUFVDUlOqlrBkJSpQBQmWQGIlZMqDcwvlasMQy6AVsZhEygp2zErbfRNB3fab67LM9ggNbsUSYPwyV7XMtXylM0+dmfo=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)-14/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95834/E2Vh2wuUCpTwmX170zhn6URBb6LM36F2w8eclPtPc+6wUq7WHSOPO/2yeyq7ytaPdTEuvwjenmG6wUjwZ8/CI2KfRCVgamBpZCst8pjgWtE=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)-16/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95836/BIGvP+y2MeA86EuNNy2oaoo/3JKAiTZWl2SOkfAqrGndtEpw//m0hjQc9klKqKfST6TytGJBIBm0d8tNDbAGcK30BHyoNEqeHZ2VRf99VcI=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(함양)외부-2/2
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95838/wKMlhG0swYvN/b5RSwsuq/BWNOSqAoIw97ntgbQf5TtCrhq/RjerPxBGIZt0DNTsShklIRntqtiApoiHB66KLNQ279iCfbMLZWwzb3My6+E=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)외부-1/1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95839/99Sut31AxUG8fPKXZWhumKWXYRhtiI6DAgIwpWmXJ1LiN1meV13JbhUpQOXN2e9Sh1Ebx8+BNIUGq0XvrbpOhf/Qx/MpZ5/n6/5Nf+sHzvs=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)-2/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95841/VNYAeADE2Z1ChLDAZK0cfWt4VWNBH1ZmNKTr+JhKnYJFfwVhqUipeP3jzUf5PcnVsdphHdyZ7H0+Gl4UpQuEIeF/uCKIsCM/fuBZcTn8v+Q=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)-4/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95843/rhyV+DqK7ghPeXMIAFHJ4SreOqrZqFnZP9rYW1ufGDdnfIqFjIklNz0qrg2nwIy8nnttUyPPBNFdPhFIYrJobra0XxCYtEuroo/ZyINEUkQ=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)-6/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95845/Wn0V43oWVjSqx5E3Mms1SgZxiHp2121MMA+wdEUwsFeS+OnxyVxd1OL/LAJVgIk4rOM+j3UsQHr6VXbHSBoQ2peHzpjo42dWIf6dWARS3u8=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)-8/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95847/hTN05IBrvSnqqWYa4CnxxNpbYhkcYgZ29Ou61TdWmwy6awZkEAnk6tHEDUXGt4uqu3maJqPaxCS4lmzXYT2tAFPL3+02C66uk8JQce9/4bE=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)-10/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95849/9o1i1V8KGbtraud+eU2DtGv+r7UcCqFcbsSEkqkITk9gnn10cvfAtIxzTBAiJJ/GgIuCbRQef26Yeq1T10O7F7XCDIGHRSxDMWw6ntuKBkc=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)-12/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95851/hik64ZdwGAXq724QnfnqyP4GmNGFq0wqqbiBO8Xq6j0IHxQ3Uuz6UbsOPYCuoc3/YXkFLmLBs5zxj7ezsUgwZ939do986tdClw3JG7soHF0=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)-14/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95853/N7Yr8lSzACmU1bcdWwi13gKvMpIY68RQnXlioMaycAIGR84RF2xzl8ZD/A1gr22nsMVquN+v6ihRG0S3ZUlAoiJzN1iKafGA8+8M/dyqJj0=
#
# CCTV 이름: [함양울산선(창녕밀양)] 부북2터널(울산)-16/17
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95855/uG2O7bZ3HTuNNT/zr+hzK3niu5xlfUGOUn20XxlmkOKfby4e3uM4GM17uwuZD74CabkA+NfP7hPhIjtsG5y5rOX6bOI6/ipzFO6R6OZasiM=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(함양)외부-1/1
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95857/xuuC5QfqjaP6JTwGK4g6D+p3TWGLU5iRce3lmynp3dMaLi9Xe4ytCzJcOdq+KY+3s/j7pat2BxXIHcu5ZE5DcTTL+U8duiZQhVp7f5MhG5Q=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(함양)-1/8
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95858/o5pOd8/MRIr+1COWw2LZZdRWs+foYJYj0IwNh/mAR6e0L4E+h5KTQoHFLz++YFmM5jMoikBwxv495BL+L2IneF1VsZQ2XETMbc75cMChAak=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(함양)-3/8
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95860/bCchWp5b7hBhl/e59ch9pCw1IPBWCJZGoaYsyFSst5ULfPSdEHrpJBrbPh/5ZxIvOdqwdUG++cQKB5eR+MMKXdabxYn1Duc89IjzAc/m5bE=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(함양)-5/8
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95862/7T+woxW79LDBSAygT/Z7i5yO23kliY8tT9wg2nrUUOAhQ9DMj2yZhMXB5fje2Q5qOpnkL5SQgOwopFGijCwT8RSpvFZPW5IBMJH8i8Jyq1U=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(함양)-7/8
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95864/gNl6QlllBJ77CaFKSN9ihvjd7kFgyXR5CM/ZIAojsMt3/wDFLKzUIihMyle21qBuTD7yPzfdEKmIUCddxFSFqNnNqeSLtr7Plqa30/b/ecU=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(울산)-1/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95866/GQdJ02r6ZolPpPh2HMASLgJnwngmEdk63nuwWPgcutactAV2EVbmBqHOtZC0WTxPx+HIsQi75uDaLh7tk3GAudNFzhaXR67l+5hVGuAS8Wo=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(울산)-3/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95868/SEbofER6FvgAWzF6leQSxI3sH4cF1gJVRsog2wj7hK0RamvYxJS0lxAIRrSx0Ab1B2Ynz8AuHi/c1BN27Q3X0BWTs+cpZ/VppENsQXMQphA=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(울산)-5/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95870/7Z6nYXShEmT8/YptFj8ldK+AJF/mjHwbVc6MO9tnhGAKb3/Y6lv6nmL3XABRwxDKyeTUIsxi0oDbbaChnsXYXisIIT1UAhPiSUHlN1GD13s=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(울산)-7/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95872/8UmoHMnv6OeX+JGI7v6u5zsSapdjWeNswNWrdNb/ffVpE82j1f2Ws93wmeCexPPKg/2KdOdrjTk4HUVdUj/JBexOBN3jl570Pq9iLuZS+98=
#
# CCTV 이름: [함양울산선(창녕밀양)] 산외1터널(울산)-9/9
# 스트리밍 URL: http://cctvsec.ktict.co.kr/95874/NEeiG/E26jiFPQXZNX06+QShWYkvlQnaXu5S6pFK6oxQG0VV6rMTGABPfKlG+s3IeYeD+Y25Bdx+ueFf6r1fMcwuN/A4ez1SFrwz6m33YqY=

# %%
def analyze_stream_from_url_2(stream_url, model, tracker_args,
                               target_classes=[0, 1, 2],
                               conf_threshold=0.3,
                               frame_resize=(720, 480),
                               max_analysis_frames=300,
                               stationary_frame_threshold=5,
                               position_threshold=2,
                               accident_frame_threshold=3,
                               frame_step=3):
    cap = cv2.VideoCapture(stream_url)
    if not cap.isOpened():
        return [], "❌ 스트림을 열 수 없습니다."

    tracker = BYTETracker(tracker_args, frame_rate=30)
    track_history = {}
    accident_ids = set()
    consecutive_accident_frames = 0
    output_frames = []
    processed_frame_count = 0  # 실제 분석한 프레임 수 기준

    while cap.isOpened() and processed_frame_count < max_analysis_frames:
        ret, frame = cap.read()
        if not ret:
            break

        resized_frame = cv2.resize(frame, frame_resize)
        results = model.predict(
            source=resized_frame,
            classes=target_classes,
            conf=conf_threshold,
            verbose=False
        )[0]

        detections = []
        for box in results.boxes:
            bbox = box.xyxy[0].cpu().numpy()
            score = float(box.conf[0])
            detections.append([*bbox, score])

        dets = np.array(detections) if detections else np.empty((0, 5))
        online_targets = tracker.update(dets, resized_frame.shape[:2], resized_frame.shape)

        for t in online_targets:
            track_id = t.track_id
            l, t_, r, b = map(int, t.tlbr)
            cx, cy = (l + r) // 2, (t_ + b) // 2

            if track_id not in track_history:
                track_history[track_id] = []
            track_history[track_id].append((cx, cy))

            history = track_history[track_id]
            if len(history) >= stationary_frame_threshold:
                movement = sum(
                    math.hypot(history[i][0] - history[i - 1][0],
                               history[i][1] - history[i - 1][1])
                    for i in range(-stationary_frame_threshold + 1, 0)
                )
                if movement < position_threshold:
                    accident_ids.add(track_id)

            color = (0, 0, 255) if track_id in accident_ids else (0, 255, 0)
            cv2.rectangle(resized_frame, (l, t_), (r, b), color, 2)
            cv2.putText(resized_frame, f'ID {track_id}', (l, t_ - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        output_frames.append(cv2.cvtColor(resized_frame, cv2.COLOR_BGR2RGB))
        processed_frame_count += 1

        if any(t.track_id in accident_ids for t in online_targets):
            consecutive_accident_frames += 1
        else:
            consecutive_accident_frames = 0

        if consecutive_accident_frames >= accident_frame_threshold:
            cap.release()
            return output_frames, "🚨 사고 상황 의심!"

        # 다음 프레임 건너뛰기 (frame_step 설정 반영)
        for _ in range(frame_step - 1):
            cap.grab()

    cap.release()
    return output_frames, "✅ 정상"

# %% [markdown]
# #**아래 셀 실행 후 .mp4 파일 업로드 필요**

# %%
def analyze_uploaded_video_with_tracking_2(model, tracker_args,
                                           target_classes=[0 ,1, 2],
                                           conf_threshold=0.3,
                                           frame_resize=(720, 480),
                                           stationary_frame_threshold=5,
                                           position_threshold=5,
                                           accident_frame_threshold=5,
                                           frame_step=3,
                                           video_path=None):

      #     업로드된 비디오 파일을 읽어 사고 여부를 추론하는 함수.

      #     Args:
      #         model: YOLOv8 모델 객체.
      #         tracker_args: BYTETracker 초기화 인자.
      #         target_classes (list[int]): 탐지할 클래스 인덱스 리스트.
      #         conf_threshold (float): 탐지 신뢰도 임계값.
      #         frame_resize (tuple): 프레임 리사이즈 크기 (width, height).
      #         stationary_frame_threshold (int): 정지 판단에 필요한 프레임 수.
      #         position_threshold (float): 정지 판단 이동 거리 임계값.
      #         accident_frame_threshold (int): 연속 사고 프레임 수 임계값.
      #         frame_step (int): 몇 프레임씩 건너뛸지 설정.
      #

      #     사고 감지 및 시각화된 프레임 리스트 반환.

    cap = cv2.VideoCapture(video_path)
    tracker = BYTETracker(tracker_args, frame_rate=30)

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_index = 0
    consecutive_accident_frames = 0
    track_history = {}
    accident_ids = set()
    output_frames = []
    flag = 0
    str1 = ""

    while frame_index < total_frames:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_index)
        ret, frame = cap.read()
        if not ret:
            print("❌ 프레임 읽기 실패")
            break

        resized_frame = cv2.resize(frame, frame_resize)
        results = model.predict(source=resized_frame, classes=target_classes,
                                conf=conf_threshold, verbose=False)[0]

        detections = []
        for box in results.boxes:
            bbox = box.xyxy[0]
            bbox = bbox.cpu().numpy() if hasattr(bbox, 'cpu') else np.array(bbox)
            x1, y1, x2, y2 = bbox
            score = float(box.conf[0])
            detections.append([x1, y1, x2, y2, score])

        dets = np.array(detections) if detections else np.empty((0, 5))
        online_targets = tracker.update(dets, (resized_frame.shape[0], resized_frame.shape[1]), resized_frame.shape)

        for t in online_targets:
            track_id = t.track_id
            l, t_, r, b = map(int, t.tlbr)
            cx, cy = (l + r) // 2, (t_ + b) // 2

            if track_id not in track_history:
                track_history[track_id] = []
            track_history[track_id].append((cx, cy))

            history = track_history[track_id]
            if len(history) >= stationary_frame_threshold:
                movement = sum(
                    math.hypot(history[i][0] - history[i-1][0],
                               history[i][1] - history[i-1][1])
                    for i in range(-stationary_frame_threshold + 1, 0)
                )
                if movement < position_threshold:
                    accident_ids.add(track_id)

            color = (0, 0, 255) if track_id in accident_ids else (0, 255, 0)
            cv2.rectangle(resized_frame, (l, t_), (r, b), color, 2)
            cv2.putText(resized_frame, f'ID {track_id}', (l, t_ - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        # 프레임 리스트에 저장 (BGR -> RGB 변환 후)
        rgb_frame = cv2.cvtColor(resized_frame, cv2.COLOR_BGR2RGB)
        output_frames.append(rgb_frame)

        if any(t.track_id in accident_ids for t in online_targets):
            consecutive_accident_frames += 1
        else:
            consecutive_accident_frames = 0

        if consecutive_accident_frames >= accident_frame_threshold:
            flag = 1

        frame_index += frame_step

    cap.release()
    if flag == 1:
      return output_frames, "🚨 사고 상황 의심!"
    else:
      return output_frames, "✅ 정상"

# %%
import gradio as gr
import cv2
import numpy as np
import requests
from ultralytics import YOLO
from types import SimpleNamespace as Namespace

# ✅ 모델 미리 로드 (성능 최적화)
model_path = "/content/drive/MyDrive/2025_1학기_캡스톤_12조/yolo_tmp_vehicle_detection(car, bus, truck).pt"
model = YOLO(model_path)

# ✅ ByteTrack 설정
tracker_args = Namespace(
    track_thresh=0.25,
    match_thresh=0.8,
    track_buffer=30,
    aspect_ratio_thresh=1.6,
    min_box_area=10,
    mot20=False
)

# ✅ CCTV 목록 요청 함수
def fetch_cctv_list(api_url):
    try:
        resp = requests.get(api_url)
        data = resp.json().get("response", {}).get("data", [])
        names = [c["cctvname"] for c in data]
        urls = [c["cctvurl"] for c in data]
        return dict(zip(names, urls))
    except:
        return {}

api_url = "https://openapi.its.go.kr:9443/cctvInfo?apiKey=7a7e0a02afe9486ab71f86210b1c6a20&type=ex&cctvType=1&minX=127.100000&maxX=128.890000&minY=34.100000&maxY=39.100000&getType=json"
name_to_url = fetch_cctv_list(api_url)

# ✅ 프레임 리스트를 비디오로 저장
def frames_to_video(frames, output_path, fps=10):
    if not frames:
        return None
    height, width, _ = frames[0].shape
    video_writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))
    for frame in frames:
        bgr = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        video_writer.write(bgr)
    video_writer.release()
    return output_path

# ✅ 통합 분석 콜백 함수
def gradio_callback(mode, video_file, selected_cctv_name,
                    conf_threshold, stationary_threshold,
                    position_threshold, accident_threshold,
                    frame_step, max_analysis_frames):
    if mode == "실시간 스트리밍 분석":
        stream_url = name_to_url.get(selected_cctv_name, "")
        if not stream_url:
            return None, "❌ 선택한 CCTV의 URL을 찾을 수 없습니다."
        output_frames, result_msg = analyze_stream_from_url_2(
            stream_url=stream_url,
            model=model,
            tracker_args=tracker_args,
            conf_threshold=conf_threshold,
            stationary_frame_threshold=stationary_threshold,
            position_threshold=position_threshold,
            accident_frame_threshold=accident_threshold,
            frame_step=frame_step,
            max_analysis_frames=max_analysis_frames  # ✅ 추가
        )
    else:
        if video_file is None:
            return None, "❌ 비디오 파일을 업로드하세요."
        output_frames, result_msg = analyze_uploaded_video_with_tracking_2(
            video_path=video_file,  # ✅ 반드시 전달해야 함
            model=model,
            tracker_args=tracker_args,
            conf_threshold=conf_threshold,
            stationary_frame_threshold=stationary_threshold,
            position_threshold=position_threshold,
            accident_frame_threshold=accident_threshold,
            frame_step=frame_step,
        )


    output_video_path = "/tmp/output_video.mp4"
    frames_to_video(output_frames, output_video_path, fps=10)
    return output_video_path, result_msg

# ✅ Gradio UI
with gr.Blocks() as demo:
    gr.Markdown("## 🚦 2025-1 Capstone Design AI Accident Detection")

    # 분석 방식 선택
    mode_radio = gr.Radio(
        choices=["실시간 스트리밍 분석", "영상 업로드 분석"],
        label="분석 방식 선택",
        value="실시간 스트리밍 분석"
    )

    # CCTV 드롭다운 (mode에 따라 표시 여부 토글)
    cctv_dropdown = gr.Dropdown(
        choices=list(name_to_url.keys()),
        label="CCTV 스트리밍 선택",
        visible=True
    )

    # 영상 업로드 입력
    video_input = gr.Video(label="영상 업로드", visible=False)

    # 파라미터 설명 블록
    gr.Markdown("""
    ### ⚙️ 분석 파라미터 설명

    - **Confidence Threshold**: 객체 탐지의 신뢰도 임계값 (0.1 ~ 1.0). 낮을수록 더 많은 객체 탐지, 높을수록 확실한 객체만 탐지.
    - **Stationary Frame Threshold**: 차량이 몇 프레임 연속 정지해야 '정지 상태'로 판단할지 설정.
    - **Position Threshold**: 이동 거리가 이 값 이하일 경우 정지로 간주함 (픽셀 단위로 거리 계산).
    - **Accident Frame Threshold**: '정지 상태'로 판단된 프레임이 몇 번 연속되면 사고로 판단할지 설정.
    - **Frame Step**: 분석 시 몇 프레임씩 건너뛸지 설정 (1이면 모든 프레임 분석, 2면 1프레임 건너뜀).
    - **Max Analysis Frames** *(실시간 전용)*: 실시간 분석 시 최대 분석할 프레임 수 (성능 및 응답 시간 조절).
    """)

    # 파라미터 슬라이더
    with gr.Row():
        conf_slider = gr.Slider(minimum=0.1, maximum=1.0, step=0.05, value=0.3, label="Confidence Threshold")
        stationary_slider = gr.Slider(minimum=1, maximum=10, step=1, value=5, label="Stationary Frame Threshold")
        position_slider = gr.Slider(minimum=1, maximum=20, step=1, value=5, label="Position Threshold")

    with gr.Row():
        accident_slider = gr.Slider(minimum=1, maximum=10, step=1, value=3, label="Accident Frame Threshold")
        frame_step_slider = gr.Slider(minimum=1, maximum=5, step=1, value=3, label="Frame Step")
        max_analysis_frames_slider = gr.Slider(minimum=100, maximum=2000, step=100, value=500, label="Max Analysis Frames (실시간 전용)")


    # 버튼 및 출력 영역
    start_button = gr.Button("분석 시작")
    output_video = gr.Video(label="분석 결과 영상")
    result_text = gr.Textbox(label="분석 결과")

    # ✅ 모드 전환 시 UI 토글
    def toggle_inputs(mode):
        return (
            gr.update(visible=(mode == "실시간 스트리밍 분석")),
            gr.update(visible=(mode == "영상 업로드 분석"))
        )

    mode_radio.change(
        fn=toggle_inputs,
        inputs=mode_radio,
        outputs=[cctv_dropdown, video_input]
    )

    # ✅ 분석 시작 버튼 클릭 시 콜백
    start_button.click(
        fn=gradio_callback,
        inputs=[
            mode_radio, video_input, cctv_dropdown,
            conf_slider, stationary_slider, position_slider,
            accident_slider, frame_step_slider, max_analysis_frames_slider  # ✅ 추가
        ],
        outputs=[output_video, result_text]
    )


# ✅ UI 실행
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://3406377539b8fba6fb.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3406377539b8fba6fb.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
